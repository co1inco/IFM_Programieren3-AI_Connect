# %%
from typing import *

# %% [markdown]
# # CPS

# %%
TVar = TypeVar('TVar')
TVal = TypeVar('TVal')

class CpsConstraint(Generic[TVal]):
    _predicates : List[Callable[[TVal, TVal], bool]]
    
    def __init__(self, predicate: Callable[[TVal, TVal], bool] = None):
        self._predicates = []
        
        if predicate is not None:
            self._predicates.append(predicate)
    
    def append(self, predicate: Callable[[TVal, TVal], bool]) -> None:
        self._predicates.append(predicate)
        
    def is_conflicting(self, a: TVal, b: TVal) -> bool:
        """
        Check if the two values a and b would conflict with any constraint
        """
        
        for p in self._predicates:
            if not p(a, b):
                return True
        return False
    
        

class CpsConfiguration(Generic[TVar, TVal]):
    _variables : List[TVar]
    _values : List[TVal]
    _constraints: Dict[TVar, Dict[TVar, CpsConstraint[TVal]]]
    
    
    def __init__(self, variables : List[str], values : List[str]):
        self._variables = variables
        self._values = values
        self._constraints = {}

    def variables(self) -> List[TVar]:
        return self._variables.copy()
    
    def values(self) -> List[TVal]:
        return self._values.copy()
    
    def _ensure_exists(self, source : TVar, target : TVar) -> None:
        if source not in self._constraints:
            self._constraints[source] = {}
        
        s = self._constraints[source]
        
        if target not in s:
            s[target] = CpsConstraint()
            
    
    def addConstraint(self, source : TVar, target : TVar, predicate : Callable[[TVal, TVal], bool]) -> None:
        """
        Add a new, one directional constraint
        """
        
        self._ensure_exists(source, target)
        
        self._constraints[source][target].append(predicate)
    
        
    def addConstraintRev(self, source : TVar, target : TVar, predicate : Callable[[TVal, TVal], bool]) -> None:
        """
        Add a new, two directional constraint.
        For the target -> source direction the parameters for the predicate are swapped, so the predicate is still called with (source, target)
        """
        
        self._ensure_exists(source, target)
        self._constraints[source][target].append(predicate)
        
        self._ensure_exists(target, source)
        self._constraints[target][source].append(lambda a, b: predicate(b, a))
    
    
    def addUnaryConstraint(self, source : TVar, predicate : Callable[[TVal], bool]) -> None:
        """
        Add a new unary constraint. 
        This is a constraint that does not have a target (eg. var must be val)
        """
        self._ensure_exists(source, None)
        
        self._constraints[source][None].append(lambda a, b: predicate(a))    
        
        
    def allNotEqual(self, variables : List[TVar]) -> None:
        """
        Constraint all variables against each other. (ie. all must have different values)
        """        
        for source in variables:
            for target in variables:
                if source == target:
                    continue
                
                self.addConstraint(source, target, lambda a, b: a != b)

                
    def notEqual(self, source : TVar, target : TVar) -> None:
        self.addConstraintRev(source, target, lambda a, b: a != b)

        
    def equal(self, source : TVar, target : TVar) -> None:
        self.addConstraintRev(source, target, lambda a, b: a == b)


    def mustBe(self, source : TVar, value : TVal) -> None:
        self.addUnaryConstraint(source, lambda a: a == value)
        

    def get_constraints(self, variable : TVar) -> Dict[TVar, CpsConstraint[TVal] ]:
        return self._constraints[variable]

# %%
class CpsState(Generic[TVar, TVal]):
    
    _parent = None
    _variable : TVar = None
    _value : TVal = None
    _config : CpsConfiguration[TVar, TVal]    
    _assigned_cache = None
    _unassigned_cache = None
    
    
    def __init__(self, config : CpsConfiguration[TVar, TVal], parent = None, variable : TVar = None, value : TVal = None):
        self._config = config
        self._parent = parent
        self._variable = variable
        self._value = value
    
    
    def assign(self, variable, value) -> 'CpsState[TVar, TVal]':
        """
        Returns a new state with the given assignment. (A state is immutable)
        """
        if variable not in self._config.variables():
            raise Exception("Invalid variable assigned: " + str(variable), ", allowed: ", self._config.variables())
        
        if value not in self._config.values():
            raise Exception("Invalid value assigned: " + str(value), ", allowed: ", self._config.values())
        
        return CpsState(self._config, self, variable, value)
    
    
    def get_assignments(self) -> Dict[TVar, TVal]:
        """
        Get all assignments
        """
        
        if self._assigned_cache is not None:
            return self._assigned_cache.copy() # return a copy so children can add to it
        
        if self._parent is None:
            return {}
        
        if self._variable is None:
            return self._parent.get_assignments()
        
        t = self._variable, self._value
        
        t2 = self._parent.get_assignments()
        t2[self._variable] = self._value
        self._assigned_cache = t2
        return t2
    
    
    def get_assignment(self, variable: TVar):
        
        assignments = self.get_assignments()
        for var in assignments:
            val = assignments[var]
            
            if var == variable:
                return val
        return None
    
    
    def get_unassigned(self) -> List[TVar]:
        """
        Get all variables that currently have no assignment
        """
        if self._unassigned_cache is not None:
            return self._unassigned_cache.copy()
        
        vars = self._config.variables()
        for a in self.get_assignments():
            if a in vars:
                vars.remove(a)
            
        self._unassigned_cache = vars
        return vars
    
    
    def get_variables(self) -> List[TVar]:
        return self._config.variables().copy()
    
    def get_values(self) -> List[TVal]:
        return self._config.values().copy()
    
    def get_constraints_for(self, variable: TVar) -> Dict[TVar, CpsConstraint[TVal]]:
        return self._config.get_constraints(variable)
    
    def is_complete(self) -> bool:
        """
        check if the CPS has assigned a value to all variables
        """
        return len(self.get_unassigned()) == 0
    
    
    def get_variables_with(self, value : TVal) -> List[TVar]:
        """
        Get all variable the value was assigned to
        """
        return [name for name, val in self.get_assignments().items() if val == value]
    
    
    def is_consistent(self) -> bool:
        
        for var in self.get_variables():
            
            # Assumes an inconsistent value was never assigned
            if self.get_assignment(var) is not None:
                continue
            
            any_consistent = False
            for val in self.get_values():
                if self.will_be_consistent(var, val):
                    any_consistent = True
            
            if not any_consistent:
                return False
        
        return True
                
    
    def will_be_consistent(self, variable: TVar, value: TVal):
        """
        Check if a variable assignment would be consistent
        """
        
        constraints = self._config.get_constraints(variable)
        
        for var in constraints:
            constraint = constraints[var] 
            
            if var is None:
                if constraint.is_conflicting(value, None):
                    return False
            else:
                otherValue = self.get_assignment(var)
                
                if otherValue is not None and constraint.is_conflicting(value, otherValue):
                    return False
                
        return True
    
    
    def get_available_values(self, variable : TVar) -> List[TVal]:
        """
        Get all values that can be assigned to variable
        """
            
        constraints = self._config.get_constraints(variable)
                   
        values = []
        
        for value in self._config.values():
        
            conflict = False
                
            for var in constraints:
                constraint = constraints[var]
                
                # if c is None it is an unary constraint
                if var is None:
                    if constraint.is_conflicting(value, None):
                        conflict = True    
                    continue
                
                otherValue = self.get_assignment(var)
                if otherValue is None: # other is not yet assigned. No check necessary
                    continue
                
                if constraint.is_conflicting(value, otherValue):
                    conflict = True
                    break
                
            if not conflict:
                values.append(value)
                
        return values

# %%
config = CpsConfiguration(["a", "b", "c"], [1, 2])
base_state = CpsState(config)

final = base_state.assign("a", 1).assign("b", 2).assign("c", 2)

display(final.is_complete())
display(final.get_variables_with(2))
# Out:
# True
# ['b', 'c']

# %% [markdown]
# # CSP Parser
#
# * Dataset: https://huggingface.co/datasets/allenai/ZebraLogicBench
#
# ### Task:
# * Read ZebraLogicBench, extract puzzles into CSP variables, domains, and constraint lists<br>
# * Example: houses, attributes, clues like “Alice lives in the red house”<br>

# %%
import pandas as pd
import re

"""
Read dataset and parse it to a dataframe
"""
zebraLogicBench = pd.read_parquet("hf://datasets/allenai/ZebraLogicBench/grid_mode/test-00000-of-00001.parquet")

"""
The column "size" tells us the number of houses and categories
(e.g. 5*6 means that we have 5 houses and 6 categories -> 30 variables)
"""

#TODO Handling categories with same values

def extract_variables(row: pd.Series) -> list[str]:
    return [v.lower() for v in re.findall(r'`([^`]+)`', str(row["puzzle"]))]

def extract_size(row: pd.Series) -> list[int]:
    size_str = row['size'].split('*')
    size_int = [int(x) for x in size_str]
    return size_int

def extract_domains(size: list[int]) -> list[int]:
    number_of_houses = size[0]
    return list(range(1, number_of_houses + 1))

def extract_clues(puzzle_text: str) -> str:
    if "## Clues:" not in puzzle_text:
        raise ValueError("No clues section found!")
    return puzzle_text.split("## Clues:", 1)[1].strip()

def extract_clue_sentences(clues : str) -> list[list[str]]:
    prepared_clues = []
    clue_sentences = re.findall(r"\d+\.\s*(.+)", clues)
    for sentence in clue_sentences:
        s = sentence.lower()
        s = re.sub(r"[^\w\s-]", "", s)
        words_of_s = s.split()
        prepared_clues.append(words_of_s)

    # TODO Change the elements of the lists for simple parsing afterwards


    return prepared_clues

def next_door(a, b):
    return a == b - 1 or a == b + 1

def right_next_to(a, b):
    return (b + 1) == a

# TODO Parse the clue sentences
# TODO Define and add the constraints per instance
def define_constraints(csp : CpsConfiguration, clues : List[List[str]], csp_variables:list[str]) -> None:
    for sentence in clues:
        entities = []
        for word in sentence:
            if word in csp_variables:
                entities.append(word)

def all_not_equal(csp: CpsConfiguration,size: list[int], csp_variables: list[str]):
    expected_number_of_variables = size[0] * size[1]
    if expected_number_of_variables != len(csp_variables):
        raise ValueError("Number of variables does not match!")
    for j in range(size[0], size[0] * size[1] + 1, size[0]):
        csp.allNotEqual(csp_variables[j - size[0]:j])

for i, row in zebraLogicBench.iterrows():
    csp_variables = extract_variables(row)
    size = extract_size(row)
    domains_int = extract_domains(size)
    domains_str = [str(x) for x in domains_int]
    clues_text = extract_clues(row['puzzle'])
    prepared_clues = extract_clue_sentences(clues_text)

    csp = CpsConfiguration(csp_variables, domains_str)
    all_not_equal(csp, size, csp_variables)
    print(csp_variables)
    # define_constraints(csp, clues, csp_variables)


# Parameter are two lists
# Constraint definition per methods on the instance
# csp = CpsConstraint = Dict[TVal, Callable[[TVal, TVal], bool]]
# Out:
# ['peter', 'alice', 'bob', 'eric', 'arnold', 'norwegian', 'german', 'dane', 'brit', 'swede', 'fantasy', 'biography', 'romance', 'mystery', 'science fiction', 'stir fry', 'grilled cheese', 'pizza', 'spaghetti', 'stew', 'red', 'green', 'blue', 'yellow', 'white', 'bird', 'dog', 'cat', 'horse', 'fish']
# ['alice', 'eric', 'arnold', 'peter', 'artist', 'engineer', 'teacher', 'doctor', 'fantasy', 'science fiction', 'mystery', 'romance', 'google pixel 6', 'iphone 13', 'oneplus 9', 'samsung galaxy s21']
# ['bob', 'alice', 'peter', 'eric', 'arnold', 'carol', 'fred', 'timothy', 'samantha', 'alice', 'meredith', 'bella', 'pop', 'hip hop', 'classical', 'jazz', 'rock', 'country', 'average', 'very tall', 'tall', 'super tall', 'very short', 'short']
# ['bob', 'arnold', 'carol', 'alice', 'peter', 'eric', 'sarah', 'janelle', 'aniya', 'kailyn', 'holly', 'penny', 'fred', 'samantha', 'bella', 'meredith', 'alice', 'timothy', 'city', 'mountain', 'camping', 'beach', 'cruise', 'cultural', 'romance', 'mystery', 'historical fiction', 'science fiction', 'biography', 'fantasy']
# ['eric', 'arnold', 'dog', 'cat']
# ['eric', 'arnold', 'alice', 'peter', 'holly', 'kailyn', 'aniya', 'janelle', 'april', 'feb', 'sept', 'jan', 'ranch', 'colonial', 'victorian', 'craftsman']
# ['eric', 'arnold', 'carnations', 'daffodils', 'red', 'yellow', 'very short', 'short']
# ['alice', 'peter', 'bob', 'eric', 'arnold', 'master', 'bachelor', 'doctorate', 'high school', 'associate', 'yellow', 'green', 'blue', 'red', 'white', 'mountain', 'camping', 'cruise', 'beach', 'city', 'huawei p50', 'google pixel 6', 'iphone 13', 'oneplus 9', 'samsung galaxy s21']
# ['peter', 'eric', 'arnold', 'white', 'red', 'yellow', 'google pixel 6', 'samsung galaxy s21', 'iphone 13', 'classical', 'rock', 'pop', 'high school', 'bachelor', 'associate']
# ['arnold', 'peter', 'eric', 'alice', 'holly', 'kailyn', 'aniya', 'janelle', 'science fiction', 'mystery', 'fantasy', 'romance', 'green', 'red', 'white', 'yellow', 'mountain', 'cruise', 'beach', 'city']
# ['eric', 'arnold', 'cat', 'dog', 'dane', 'brit', 'doctor', 'engineer', 'soccer', 'basketball', 'prince', 'pall mall']
# ['bob', 'arnold', 'peter', 'eric', 'carol', 'alice', 'lilies', 'daffodils', 'carnations', 'tulips', 'iris', 'roses']
# ['arnold', 'alice', 'peter', 'eric', 'green', 'red', 'white', 'yellow']
# ['alice', 'bob', 'arnold', 'peter', 'eric', 'tennis', 'baseball', 'soccer', 'basketball', 'swimming']
# ['bob', 'eric', 'arnold', 'alice', 'peter', 'blue', 'green', 'white', 'yellow', 'red', 'huawei p50', 'samsung galaxy s21', 'oneplus 9', 'iphone 13', 'google pixel 6', 'artist', 'teacher', 'doctor', 'engineer', 'lawyer']
# ['eric', 'peter', 'alice', 'arnold', 'tesla model 3', 'honda civic', 'toyota camry', 'ford f150', 'jan', 'april', 'sept', 'feb', 'painting', 'cooking', 'gardening', 'photography']
# ['arnold', 'bob', 'alice', 'eric', 'peter', 'basketball', 'soccer', 'tennis', 'baseball', 'swimming', 'dog', 'fish', 'horse', 'bird', 'cat', 'oneplus 9', 'google pixel 6', 'samsung galaxy s21', 'iphone 13', 'huawei p50', 'black', 'red', 'brown', 'blonde', 'gray', 'modern', 'craftsman', 'victorian', 'ranch', 'colonial']
# ['arnold', 'eric', 'colonial', 'victorian', 'iphone 13', 'samsung galaxy s21']
# ['alice', 'arnold', 'eric', 'bob', 'peter', 'watermelon', 'cherry', 'dragonfruit', 'lime', 'desert', 'hip hop', 'classical', 'rock', 'pop', 'jazz', 'grilled cheese', 'pizza', 'spaghetti', 'stir fry', 'stew', 'tea', 'root beer', 'milk', 'water', 'coffee']
# ['eric', 'arnold', 'peter', 'milk', 'tea', 'water', 'soccer', 'basketball', 'tennis', 'bird', 'horse', 'cat', 'mystery', 'science fiction', 'romance']
# ['alice', 'peter', 'eric', 'arnold', 'bird', 'cat', 'dog', 'fish', 'iphone 13', 'google pixel 6', 'oneplus 9', 'samsung galaxy s21']
# ['eric', 'alice', 'peter', 'arnold', 'bob', 'cat', 'dog', 'bird', 'fish', 'hamster', 'pall mall', 'blends', 'prince', 'dunhill', 'blue master', 'watermelon', 'desert', 'dragonfruit', 'cherry', 'lime', 'google pixel 6', 'oneplus 9', 'samsung galaxy s21', 'iphone 13', 'huawei p50', 'baseball', 'soccer', 'basketball', 'swimming', 'tennis']
# ['eric', 'arnold', 'peter', 'pop', 'rock', 'classical', 'tennis', 'soccer', 'basketball', 'blue master', 'pall mall', 'prince', 'holly', 'aniya', 'janelle']
# ['arnold', 'eric', 'peter', 'alice', 'romance', 'mystery', 'fantasy', 'science fiction', 'soccer', 'basketball', 'swimming', 'tennis']
# ['arnold', 'peter', 'bob', 'alice', 'eric', 'iphone 13', 'oneplus 9', 'samsung galaxy s21', 'google pixel 6', 'huawei p50']
# ['eric', 'arnold', 'alice', 'peter', 'craftsman', 'ranch', 'victorian', 'colonial', 'water', 'tea', 'milk', 'coffee']
# ['arnold', 'peter', 'bob', 'alice', 'eric', 'spaghetti', 'pizza', 'stew', 'grilled cheese', 'stir fry']
# ['eric', 'arnold', 'alice', 'peter', 'tall', 'very short', 'average', 'short', 'tea', 'coffee', 'water', 'milk', 'fred', 'meredith', 'bella', 'samantha', 'holly', 'janelle', 'aniya', 'kailyn']
# ['arnold', 'peter', 'eric', 'engineer', 'teacher', 'doctor', 'white', 'yellow', 'red', 'carnations', 'lilies', 'daffodils', 'pizza', 'spaghetti', 'grilled cheese', 'average', 'short', 'very short']
# ['arnold', 'bob', 'alice', 'eric', 'peter', 'dane', 'swede', 'german', 'brit', 'norwegian', 'gardening', 'painting', 'knitting', 'photography', 'cooking', 'dragonfruit', 'lime', 'watermelon', 'desert', 'cherry', 'brown', 'gray', 'black', 'blonde', 'red', 'baseball', 'soccer', 'swimming', 'tennis', 'basketball']
# ['peter', 'eric', 'bob', 'arnold', 'alice', 'dog', 'cat', 'fish', 'horse', 'bird']
# ['eric', 'carol', 'bob', 'peter', 'arnold', 'alice', 'stew', 'stir fry', 'soup', 'grilled cheese', 'pizza', 'spaghetti', 'root beer', 'milk', 'boba tea', 'water', 'coffee', 'tea', 'super tall', 'short', 'tall', 'very short', 'very tall', 'average', 'sept', 'feb', 'may', 'mar', 'jan', 'april']
# ['bob', 'arnold', 'alice', 'peter', 'eric', 'cooking', 'gardening', 'painting', 'photography', 'knitting', 'swimming', 'tennis', 'soccer', 'baseball', 'basketball', 'ranch', 'craftsman', 'victorian', 'modern', 'colonial', 'timothy', 'samantha', 'bella', 'meredith', 'fred', 'average', 'very tall', 'very short', 'short', 'tall']
# ['eric', 'alice', 'arnold', 'peter', 'red', 'green', 'white', 'yellow', 'bird', 'fish', 'horse', 'cat', 'master', 'associate', 'high school', 'bachelor']
# ['carol', 'arnold', 'eric', 'alice', 'bob', 'peter', 'bachelor', 'high school', 'master', 'associate', 'trade school', 'doctorate', 'purple', 'yellow', 'white', 'red', 'blue', 'green', 'swede', 'dane', 'norwegian', 'chinese', 'brit', 'german', 'feb', 'may', 'sept', 'april', 'jan', 'mar']
# ['peter', 'arnold', 'eric', 'toyota camry', 'ford f150', 'tesla model 3', 'ranch', 'colonial', 'victorian', 'cat', 'dog', 'fish', 'engineer', 'doctor', 'teacher', 'city', 'mountain', 'beach']
# ['peter', 'alice', 'arnold', 'eric', 'victorian', 'ranch', 'craftsman', 'colonial', 'pop', 'classical', 'rock', 'jazz', 'roses', 'lilies', 'carnations', 'daffodils', 'city', 'beach', 'mountain', 'cruise', 'red', 'white', 'yellow', 'green']
# ['bob', 'peter', 'arnold', 'eric', 'alice', 'stew', 'stir fry', 'spaghetti', 'grilled cheese', 'pizza', 'watermelon', 'lime', 'desert', 'dragonfruit', 'cherry', 'fantasy', 'biography', 'mystery', 'science fiction', 'romance', 'photography', 'knitting', 'cooking', 'gardening', 'painting']
# ['arnold', 'eric', 'high school', 'associate', 'aniya', 'holly']
# ['arnold', 'eric', 'peter', 'alice', 'doctor', 'engineer', 'artist', 'teacher']
# ['eric', 'arnold', 'pizza', 'grilled cheese', 'tesla model 3', 'ford f150']
# ['peter', 'eric', 'arnold', 'red', 'white', 'yellow', 'fred', 'meredith', 'bella']
# ['eric', 'alice', 'arnold', 'peter', 'bob', 'average', 'tall', 'short', 'very short', 'very tall', 'cooking', 'knitting', 'photography', 'gardening', 'painting', 'cruise', 'city', 'mountain', 'beach', 'camping', 'ford f150', 'toyota camry', 'tesla model 3', 'honda civic', 'bmw 3 series', 'bachelor', 'doctorate', 'master', 'high school', 'associate']
# ['arnold', 'eric', 'april', 'sept', 'red', 'yellow', 'dane', 'brit', 'black', 'brown', 'fred', 'bella']
# ['eric', 'arnold', 'alice', 'peter', 'pizza', 'spaghetti', 'grilled cheese', 'stew', 'pop', 'classical', 'jazz', 'rock']
# ['eric', 'arnold', 'alice', 'bob', 'peter', 'cruise', 'city', 'mountain', 'camping', 'beach', 'fred', 'bella', 'meredith', 'samantha', 'timothy', 'bird', 'fish', 'dog', 'hamster', 'cat', 'basketball', 'swimming', 'tennis', 'baseball', 'soccer', 'tea', 'coffee', 'water', 'milk', 'root beer']
# ['arnold', 'eric', 'short', 'very short', 'cat', 'dog', 'brit', 'dane', 'yellow', 'red', 'aniya', 'holly']
# ['arnold', 'eric', 'very short', 'short', 'daffodils', 'carnations', 'black', 'brown', 'pall mall', 'prince']
# ['eric', 'peter', 'arnold', 'alice', 'bob', 'bird', 'dog', 'hamster', 'fish', 'cat', 'fantasy', 'romance', 'science fiction', 'biography', 'mystery', 'basketball', 'soccer', 'tennis', 'baseball', 'swimming', 'pall mall', 'prince', 'blue master', 'blends', 'dunhill']
# ['arnold', 'eric', 'pall mall', 'prince', 'daffodils', 'carnations', 'basketball', 'soccer']
# ['alice', 'arnold', 'peter', 'eric', 'black', 'blonde', 'brown', 'red']
# ['alice', 'carol', 'eric', 'peter', 'bob', 'arnold', 'classical', 'hip hop', 'jazz', 'pop', 'rock', 'country', 'sarah', 'penny', 'aniya', 'janelle', 'kailyn', 'holly', 'alice', 'fred', 'timothy', 'bella', 'samantha', 'meredith', 'very short', 'tall', 'short', 'very tall', 'super tall', 'average', 'bird', 'dog', 'horse', 'rabbit', 'cat', 'fish']
# ['arnold', 'eric', 'short', 'very short']
# ['eric', 'arnold', 'pop', 'rock', 'dog', 'cat', 'pizza', 'grilled cheese', 'brit', 'dane', 'april', 'sept']
# ['arnold', 'peter', 'eric', 'alice', 'kailyn', 'holly', 'aniya', 'janelle']
# ['arnold', 'eric', 'alice', 'peter', 'feb', 'jan', 'april', 'sept', 'black', 'blonde', 'brown', 'red', 'colonial', 'ranch', 'victorian', 'craftsman', 'engineer', 'artist', 'doctor', 'teacher', 'cherry', 'dragonfruit', 'desert', 'watermelon']
# ['bob', 'arnold', 'peter', 'eric', 'alice', 'mystery', 'science fiction', 'biography', 'fantasy', 'romance', 'samantha', 'timothy', 'fred', 'meredith', 'bella']
# ['eric', 'arnold', 'bob', 'peter', 'alice', 'dunhill', 'blue master', 'blends', 'pall mall', 'prince', 'lawyer', 'artist', 'engineer', 'doctor', 'teacher', 'ford f150', 'toyota camry', 'honda civic', 'bmw 3 series', 'tesla model 3', 'watermelon', 'cherry', 'dragonfruit', 'desert', 'lime', 'stew', 'spaghetti', 'grilled cheese', 'pizza', 'stir fry']
# ['arnold', 'peter', 'eric', 'short', 'average', 'very short']
# ['eric', 'alice', 'peter', 'arnold', 'bachelor', 'high school', 'associate', 'master', 'holly', 'janelle', 'aniya', 'kailyn', 'fish', 'horse', 'cat', 'bird', 'jan', 'feb', 'sept', 'april', 'rock', 'pop', 'jazz', 'classical']
# ['peter', 'arnold', 'alice', 'eric', 'roses', 'daffodils', 'carnations', 'lilies', 'photography', 'painting', 'cooking', 'gardening', 'dog', 'fish', 'bird', 'cat', 'red', 'yellow', 'green', 'white', 'craftsman', 'colonial', 'ranch', 'victorian']
# ['eric', 'arnold', 'peter', 'engineer', 'teacher', 'doctor', 'water', 'milk', 'tea', 'google pixel 6', 'samsung galaxy s21', 'iphone 13']
# ['bob', 'alice', 'eric', 'peter', 'arnold', 'google pixel 6', 'samsung galaxy s21', 'huawei p50', 'iphone 13', 'oneplus 9']
# ['peter', 'eric', 'arnold', 'soccer', 'basketball', 'tennis', 'victorian', 'colonial', 'ranch', 'fish', 'dog', 'cat', 'sept', 'april', 'jan', 'swede', 'dane', 'brit']
# ['arnold', 'peter', 'eric', 'soccer', 'tennis', 'basketball', 'april', 'sept', 'jan', 'city', 'beach', 'mountain', 'average', 'short', 'very short', 'lilies', 'carnations', 'daffodils']
# ['arnold', 'peter', 'carol', 'alice', 'bob', 'eric', 'alice', 'timothy', 'bella', 'meredith', 'fred', 'samantha', 'desert', 'cherry', 'watermelon', 'blueberry', 'lime', 'dragonfruit']
# ['peter', 'eric', 'arnold', 'daffodils', 'carnations', 'lilies', 'high school', 'bachelor', 'associate', 'dog', 'fish', 'cat', 'desert', 'watermelon', 'cherry']
# ['arnold', 'eric', 'soccer', 'basketball']
# ['eric', 'arnold', 'peter', 'aniya', 'holly', 'janelle']
# ['arnold', 'eric', 'engineer', 'doctor']
# ['eric', 'arnold', 'holly', 'aniya']
# ['arnold', 'eric', 'peter', 'romance', 'mystery', 'science fiction', 'grilled cheese', 'pizza', 'spaghetti', 'desert', 'watermelon', 'cherry']
# ['alice', 'peter', 'arnold', 'eric', 'prince', 'dunhill', 'blue master', 'pall mall', 'swimming', 'basketball', 'soccer', 'tennis', 'coffee', 'water', 'milk', 'tea']
# ['peter', 'arnold', 'eric', 'blonde', 'black', 'brown', 'jan', 'april', 'sept']
# ['eric', 'arnold', 'peter', 'alice', 'spaghetti', 'pizza', 'stew', 'grilled cheese', 'tesla model 3', 'honda civic', 'toyota camry', 'ford f150', 'fish', 'cat', 'bird', 'horse']
# ['carol', 'eric', 'bob', 'peter', 'arnold', 'alice', 'cultural', 'beach', 'mountain', 'cruise', 'camping', 'city', 'chinese', 'brit', 'norwegian', 'swede', 'dane', 'german', 'lime', 'desert', 'watermelon', 'blueberry', 'dragonfruit', 'cherry']
# ['peter', 'alice', 'bob', 'eric', 'arnold', 'lilies', 'carnations', 'daffodils', 'roses', 'tulips', 'swimming', 'soccer', 'tennis', 'basketball', 'baseball', 'aniya', 'kailyn', 'janelle', 'penny', 'holly']
# ['alice', 'bob', 'eric', 'arnold', 'peter', 'carol', 'short', 'tall', 'very short', 'average', 'very tall', 'super tall', 'rock', 'jazz', 'classical', 'country', 'hip hop', 'pop', 'samantha', 'alice', 'fred', 'bella', 'meredith', 'timothy']
# ['arnold', 'eric', 'samsung galaxy s21', 'iphone 13', 'dog', 'cat']
# ['arnold', 'bob', 'peter', 'eric', 'alice', 'carol', 'april', 'feb', 'mar', 'jan', 'may', 'sept', 'city', 'beach', 'mountain', 'cruise', 'cultural', 'camping', 'blue', 'white', 'green', 'purple', 'red', 'yellow']
# ['bob', 'arnold', 'alice', 'eric', 'peter', 'stew', 'spaghetti', 'grilled cheese', 'pizza', 'stir fry', 'green', 'blue', 'yellow', 'red', 'white', 'swede', 'brit', 'dane', 'german', 'norwegian', 'fantasy', 'biography', 'romance', 'mystery', 'science fiction', 'timothy', 'samantha', 'meredith', 'fred', 'bella']
# ['eric', 'peter', 'arnold', 'alice', 'spaghetti', 'pizza', 'stew', 'grilled cheese', 'coffee', 'milk', 'tea', 'water', 'cherry', 'desert', 'dragonfruit', 'watermelon']
# ['arnold', 'eric', 'yellow', 'red', 'prince', 'pall mall', 'mystery', 'science fiction', 'dane', 'brit', 'engineer', 'doctor']
# ['alice', 'peter', 'eric', 'bob', 'carol', 'arnold', 'dunhill', 'blends', 'blue master', 'yellow monster', 'pall mall', 'prince', 'fantasy', 'romance', 'science fiction', 'mystery', 'historical fiction', 'biography']
# ['arnold', 'peter', 'eric', 'fish', 'dog', 'cat']
# ['peter', 'eric', 'arnold', 'bob', 'alice', 'milk', 'tea', 'root beer', 'water', 'coffee', 'blue', 'white', 'red', 'green', 'yellow', 'samantha', 'meredith', 'timothy', 'bella', 'fred', 'modern', 'ranch', 'victorian', 'colonial', 'craftsman', 'samsung galaxy s21', 'iphone 13', 'huawei p50', 'oneplus 9', 'google pixel 6']
# ['carol', 'alice', 'eric', 'bob', 'peter', 'arnold', 'jan', 'mar', 'feb', 'may', 'april', 'sept', 'city', 'camping', 'beach', 'cruise', 'cultural', 'mountain', 'milk', 'water', 'tea', 'root beer', 'coffee', 'boba tea']
# ['eric', 'arnold', 'peter', 'grilled cheese', 'pizza', 'spaghetti', 'pop', 'rock', 'classical', 'water', 'milk', 'tea']
# ['alice', 'arnold', 'eric', 'peter', 'water', 'tea', 'coffee', 'milk', 'master', 'associate', 'high school', 'bachelor', 'kailyn', 'holly', 'aniya', 'janelle', 'yellow', 'white', 'green', 'red']
# ['eric', 'arnold', 'dane', 'brit']
# ['alice', 'peter', 'bob', 'eric', 'arnold', 'fish', 'dog', 'horse', 'bird', 'cat', 'honda civic', 'bmw 3 series', 'ford f150', 'toyota camry', 'tesla model 3', 'coffee', 'tea', 'root beer', 'milk', 'water']
# ['eric', 'arnold', 'peter', 'short', 'very short', 'average']
# ['arnold', 'peter', 'eric', 'alice', 'cat', 'fish', 'bird', 'dog']
# ['peter', 'arnold', 'alice', 'eric', 'tall', 'short', 'very short', 'average', 'april', 'jan', 'sept', 'feb', 'red', 'black', 'brown', 'blonde', 'science fiction', 'fantasy', 'romance', 'mystery']
# ['arnold', 'eric', 'horse', 'cat']
# ['arnold', 'peter', 'bob', 'eric', 'carol', 'alice', 'horse', 'rabbit', 'fish', 'cat', 'bird', 'dog', 'engineer', 'nurse', 'lawyer', 'teacher', 'artist', 'doctor', 'basketball', 'volleyball', 'soccer', 'tennis', 'baseball', 'swimming', 'average', 'tall', 'short', 'very short', 'very tall', 'super tall']
# ['arnold', 'eric', 'peter', 'associate', 'bachelor', 'high school', 'water', 'tea', 'milk', 'science fiction', 'mystery', 'romance', 'photography', 'cooking', 'gardening', 'ford f150', 'tesla model 3', 'toyota camry']
# ['arnold', 'alice', 'eric', 'peter', 'bob', 'blends', 'prince', 'dunhill', 'pall mall', 'blue master']
# ['arnold', 'peter', 'eric', 'carnations', 'lilies', 'daffodils', 'dane', 'swede', 'brit', 'cherry', 'watermelon', 'desert']
# ['alice', 'carol', 'eric', 'peter', 'arnold', 'bob', 'pall mall', 'yellow monster', 'dunhill', 'blends', 'blue master', 'prince', 'watermelon', 'dragonfruit', 'lime', 'desert', 'blueberry', 'cherry']
# ['eric', 'bob', 'peter', 'arnold', 'alice', 'associate', 'doctorate', 'high school', 'bachelor', 'master', 'sept', 'april', 'mar', 'feb', 'jan']
# ['eric', 'peter', 'arnold', 'water', 'milk', 'tea', 'carnations', 'lilies', 'daffodils', 'pall mall', 'prince', 'blue master']
# ['alice', 'peter', 'eric', 'bob', 'carol', 'arnold', 'baseball', 'basketball', 'swimming', 'tennis', 'soccer', 'volleyball', 'purple', 'green', 'white', 'red', 'yellow', 'blue', 'red', 'auburn', 'blonde', 'black', 'gray', 'brown', 'stew', 'spaghetti', 'stir fry', 'grilled cheese', 'soup', 'pizza']
# ['eric', 'arnold', 'peter', 'bob', 'alice', 'carol', 'jazz', 'country', 'pop', 'classical', 'rock', 'hip hop', 'mediterranean', 'modern', 'colonial', 'ranch', 'victorian', 'craftsman', 'tennis', 'baseball', 'soccer', 'volleyball', 'swimming', 'basketball', 'science fiction', 'historical fiction', 'mystery', 'biography', 'fantasy', 'romance']
# ['peter', 'eric', 'arnold', 'alice', 'bob', 'google pixel 6', 'samsung galaxy s21', 'huawei p50', 'oneplus 9', 'iphone 13']
# ['eric', 'arnold', 'peter', 'alice', 'carol', 'bob', 'mystery', 'biography', 'science fiction', 'romance', 'fantasy', 'historical fiction', 'water', 'milk', 'boba tea', 'coffee', 'tea', 'root beer', 'blonde', 'red', 'gray', 'black', 'auburn', 'brown', 'may', 'mar', 'sept', 'jan', 'april', 'feb']
# ['eric', 'bob', 'carol', 'arnold', 'peter', 'alice', 'blends', 'prince', 'dunhill', 'yellow monster', 'blue master', 'pall mall', 'auburn', 'gray', 'blonde', 'black', 'red', 'brown', 'boba tea', 'root beer', 'water', 'tea', 'coffee', 'milk', 'artist', 'nurse', 'teacher', 'doctor', 'engineer', 'lawyer']
# ['peter', 'arnold', 'eric', 'bob', 'alice', 'average', 'very tall', 'very short', 'short', 'tall', 'prince', 'dunhill', 'blends', 'pall mall', 'blue master', 'lime', 'cherry', 'dragonfruit', 'watermelon', 'desert', 'oneplus 9', 'samsung galaxy s21', 'iphone 13', 'huawei p50', 'google pixel 6']
# ['peter', 'arnold', 'eric', 'bella', 'fred', 'meredith', 'dane', 'brit', 'swede', 'april', 'jan', 'sept']
# ['eric', 'peter', 'alice', 'arnold', 'sept', 'feb', 'april', 'jan', 'romance', 'fantasy', 'mystery', 'science fiction', 'roses', 'daffodils', 'lilies', 'carnations', 'cruise', 'city', 'mountain', 'beach']
# ['alice', 'arnold', 'eric', 'peter', 'bob', 'carol', 'huawei p50', 'iphone 13', 'xiaomi mi 11', 'samsung galaxy s21', 'google pixel 6', 'oneplus 9']
# ['eric', 'peter', 'arnold', 'ford f150', 'tesla model 3', 'toyota camry']
# ['arnold', 'peter', 'eric', 'alice', 'dane', 'swede', 'brit', 'norwegian']
# ['eric', 'arnold', 'prince', 'pall mall']
# ['eric', 'arnold', 'peter', 'ford f150', 'tesla model 3', 'toyota camry', 'beach', 'mountain', 'city', 'dane', 'swede', 'brit', 'blonde', 'black', 'brown', 'colonial', 'ranch', 'victorian']
# ['eric', 'bob', 'carol', 'peter', 'alice', 'arnold', 'spaghetti', 'stew', 'grilled cheese', 'soup', 'stir fry', 'pizza']
# ['peter', 'eric', 'arnold', 'bachelor', 'associate', 'high school', 'photography', 'gardening', 'cooking', 'water', 'milk', 'tea']
# ['alice', 'arnold', 'eric', 'peter', 'master', 'bachelor', 'associate', 'high school', 'tennis', 'soccer', 'swimming', 'basketball', 'teacher', 'engineer', 'doctor', 'artist', 'carnations', 'daffodils', 'lilies', 'roses', 'very short', 'average', 'tall', 'short']
# ['arnold', 'peter', 'eric', 'tennis', 'basketball', 'soccer', 'classical', 'rock', 'pop']
# ['eric', 'arnold', 'carnations', 'daffodils', 'brit', 'dane', 'desert', 'cherry', 'basketball', 'soccer']
# ['arnold', 'peter', 'alice', 'eric', 'black', 'red', 'blonde', 'brown', 'engineer', 'artist', 'doctor', 'teacher', 'coffee', 'water', 'tea', 'milk']
# ['alice', 'peter', 'arnold', 'eric', 'pizza', 'stew', 'grilled cheese', 'spaghetti']
# ['bob', 'alice', 'eric', 'arnold', 'peter', 'red', 'brown', 'black', 'blonde', 'gray', 'daffodils', 'carnations', 'tulips', 'roses', 'lilies']
# ['eric', 'arnold', 'cat', 'dog', 'carnations', 'daffodils', 'photography', 'gardening', 'brown', 'black', 'mountain', 'beach']
# ['alice', 'eric', 'arnold', 'peter', 'painting', 'gardening', 'photography', 'cooking', 'romance', 'science fiction', 'mystery', 'fantasy', 'city', 'beach', 'mountain', 'cruise', 'rock', 'pop', 'classical', 'jazz', 'high school', 'associate', 'bachelor', 'master']
# ['eric', 'peter', 'arnold', 'sept', 'april', 'jan', 'tesla model 3', 'toyota camry', 'ford f150', 'brown', 'black', 'blonde', 'aniya', 'janelle', 'holly']
# ['bob', 'eric', 'peter', 'carol', 'alice', 'arnold', 'rock', 'classical', 'pop', 'hip hop', 'jazz', 'country']
# ['peter', 'eric', 'alice', 'arnold', 'bob', 'fish', 'dog', 'bird', 'cat', 'horse', 'beach', 'city', 'mountain', 'camping', 'cruise', 'google pixel 6', 'huawei p50', 'samsung galaxy s21', 'iphone 13', 'oneplus 9']
# ['carol', 'peter', 'arnold', 'bob', 'eric', 'alice', 'iphone 13', 'google pixel 6', 'oneplus 9', 'huawei p50', 'samsung galaxy s21', 'xiaomi mi 11', 'gray', 'auburn', 'red', 'brown', 'black', 'blonde', 'coffee', 'water', 'root beer', 'tea', 'milk', 'boba tea', 'classical', 'jazz', 'rock', 'country', 'hip hop', 'pop']
# ['alice', 'peter', 'eric', 'arnold', 'coffee', 'tea', 'milk', 'water', 'fantasy', 'science fiction', 'mystery', 'romance', 'red', 'black', 'blonde', 'brown']
# ['bob', 'peter', 'eric', 'alice', 'carol', 'arnold', 'cruise', 'mountain', 'beach', 'camping', 'city', 'cultural', 'german', 'swede', 'brit', 'chinese', 'dane', 'norwegian']
# ['carol', 'bob', 'arnold', 'peter', 'alice', 'eric', 'mystery', 'fantasy', 'science fiction', 'romance', 'historical fiction', 'biography']
# ['eric', 'alice', 'arnold', 'bob', 'peter', 'carol', 'woodworking', 'knitting', 'cooking', 'gardening', 'painting', 'photography', 'pall mall', 'blue master', 'blends', 'prince', 'dunhill', 'yellow monster']
# ['peter', 'eric', 'arnold', 'cat', 'horse', 'bird', 'yellow', 'white', 'red', 'brit', 'swede', 'dane', 'daffodils', 'lilies', 'carnations']
# ['eric', 'peter', 'alice', 'arnold', 'red', 'white', 'yellow', 'green', 'feb', 'sept', 'jan', 'april', 'aniya', 'janelle', 'kailyn', 'holly', 'pall mall', 'prince', 'blue master', 'dunhill', 'lilies', 'daffodils', 'carnations', 'roses']
# ['alice', 'eric', 'peter', 'bob', 'arnold', 'soccer', 'baseball', 'swimming', 'tennis', 'basketball', 'modern', 'victorian', 'colonial', 'craftsman', 'ranch', 'beach', 'city', 'cruise', 'mountain', 'camping', 'artist', 'engineer', 'lawyer', 'doctor', 'teacher', 'penny', 'aniya', 'janelle', 'holly', 'kailyn']
# ['arnold', 'eric', 'colonial', 'victorian', 'dane', 'brit', 'beach', 'mountain', 'dog', 'cat', 'science fiction', 'mystery']
# ['eric', 'arnold', 'high school', 'associate', 'tea', 'water']
# ['peter', 'eric', 'arnold', 'blue master', 'prince', 'pall mall', 'fred', 'meredith', 'bella', 'holly', 'aniya', 'janelle', 'cat', 'horse', 'bird']
# ['bob', 'arnold', 'alice', 'peter', 'eric', 'oneplus 9', 'google pixel 6', 'iphone 13', 'huawei p50', 'samsung galaxy s21', 'blue', 'red', 'yellow', 'green', 'white', 'janelle', 'penny', 'holly', 'aniya', 'kailyn', 'german', 'norwegian', 'swede', 'dane', 'brit', 'spaghetti', 'grilled cheese', 'stew', 'pizza', 'stir fry']
# ['alice', 'arnold', 'peter', 'carol', 'bob', 'eric', 'mountain', 'beach', 'city', 'cruise', 'camping', 'cultural', 'yellow monster', 'pall mall', 'prince', 'dunhill', 'blue master', 'blends', 'swimming', 'soccer', 'tennis', 'basketball', 'volleyball', 'baseball']
# ['eric', 'alice', 'arnold', 'carol', 'peter', 'bob', 'high school', 'trade school', 'bachelor', 'doctorate', 'master', 'associate', 'purple', 'blue', 'white', 'red', 'green', 'yellow', 'cultural', 'cruise', 'beach', 'mountain', 'camping', 'city', 'science fiction', 'biography', 'historical fiction', 'fantasy', 'romance', 'mystery']
# ['peter', 'arnold', 'eric', 'carol', 'alice', 'bob', 'country', 'classical', 'pop', 'hip hop', 'jazz', 'rock', 'modern', 'mediterranean', 'victorian', 'craftsman', 'ranch', 'colonial', 'huawei p50', 'iphone 13', 'google pixel 6', 'oneplus 9', 'xiaomi mi 11', 'samsung galaxy s21', 'hamster', 'dog', 'cat', 'rabbit', 'fish', 'bird']
# ['arnold', 'peter', 'eric', 'basketball', 'tennis', 'soccer', 'romance', 'science fiction', 'mystery', 'sept', 'april', 'jan', 'lilies', 'daffodils', 'carnations']
# ['alice', 'eric', 'arnold', 'bob', 'peter', 'lilies', 'roses', 'carnations', 'tulips', 'daffodils', 'sept', 'april', 'feb', 'mar', 'jan', 'pizza', 'grilled cheese', 'spaghetti', 'stir fry', 'stew', 'colonial', 'craftsman', 'victorian', 'ranch', 'modern']
# ['peter', 'eric', 'arnold', 'mountain', 'beach', 'city', 'gardening', 'cooking', 'photography', 'tennis', 'soccer', 'basketball', 'carnations', 'daffodils', 'lilies', 'desert', 'cherry', 'watermelon']
# ['alice', 'arnold', 'eric', 'peter', 'fish', 'cat', 'dog', 'bird', 'cruise', 'mountain', 'city', 'beach']
# ['arnold', 'eric', 'peter', 'carnations', 'lilies', 'daffodils', 'black', 'brown', 'blonde', 'soccer', 'basketball', 'tennis', 'colonial', 'ranch', 'victorian', 'fish', 'dog', 'cat']
# ['arnold', 'peter', 'eric', 'romance', 'mystery', 'science fiction', 'sept', 'april', 'jan', 'brit', 'dane', 'swede']
# ['eric', 'arnold', 'alice', 'peter', 'bob', 'german', 'norwegian', 'brit', 'dane', 'swede', 'swimming', 'soccer', 'baseball', 'basketball', 'tennis', 'blonde', 'brown', 'red', 'black', 'gray']
# ['bob', 'peter', 'arnold', 'alice', 'eric', 'blue master', 'dunhill', 'prince', 'blends', 'pall mall', 'rock', 'classical', 'hip hop', 'pop', 'jazz', 'feb', 'april', 'sept', 'jan', 'mar', 'romance', 'science fiction', 'mystery', 'biography', 'fantasy']
# ['bob', 'peter', 'carol', 'eric', 'alice', 'arnold', 'coffee', 'milk', 'water', 'root beer', 'tea', 'boba tea', 'tulips', 'lilies', 'daffodils', 'iris', 'roses', 'carnations', 'doctor', 'artist', 'nurse', 'engineer', 'teacher', 'lawyer', 'woodworking', 'photography', 'cooking', 'painting', 'knitting', 'gardening']
# ['alice', 'peter', 'arnold', 'eric', 'tall', 'short', 'very short', 'average', 'photography', 'painting', 'cooking', 'gardening']
# ['peter', 'alice', 'eric', 'arnold', 'horse', 'cat', 'fish', 'bird', 'oneplus 9', 'google pixel 6', 'iphone 13', 'samsung galaxy s21', 'red', 'white', 'yellow', 'green', 'colonial', 'victorian', 'ranch', 'craftsman']
# ['bob', 'peter', 'alice', 'eric', 'arnold', 'science fiction', 'romance', 'fantasy', 'mystery', 'biography']
# ['arnold', 'peter', 'alice', 'eric', 'rock', 'jazz', 'pop', 'classical', 'janelle', 'aniya', 'kailyn', 'holly', 'master', 'high school', 'bachelor', 'associate']
# ['eric', 'arnold', 'sept', 'april', 'black', 'brown', 'daffodils', 'carnations', 'associate', 'high school', 'tesla model 3', 'ford f150']
# ['eric', 'peter', 'arnold', 'ford f150', 'tesla model 3', 'toyota camry', 'samsung galaxy s21', 'google pixel 6', 'iphone 13']
# ['peter', 'eric', 'alice', 'bob', 'arnold', 'mystery', 'fantasy', 'biography', 'science fiction', 'romance', 'mountain', 'camping', 'city', 'beach', 'cruise', 'holly', 'janelle', 'kailyn', 'penny', 'aniya']
# ['alice', 'peter', 'bob', 'eric', 'arnold', 'tulips', 'daffodils', 'lilies', 'roses', 'carnations', 'fred', 'bella', 'timothy', 'meredith', 'samantha', 'high school', 'bachelor', 'doctorate', 'master', 'associate', 'cat', 'fish', 'dog', 'horse', 'bird']
# ['eric', 'peter', 'arnold', 'alice', 'victorian', 'ranch', 'colonial', 'craftsman', 'teacher', 'engineer', 'doctor', 'artist', 'prince', 'dunhill', 'pall mall', 'blue master', 'pop', 'rock', 'classical', 'jazz', 'very short', 'tall', 'average', 'short']
# ['eric', 'arnold', 'ford f150', 'tesla model 3', 'grilled cheese', 'pizza', 'soccer', 'basketball', 'water', 'tea']
# ['peter', 'eric', 'bob', 'arnold', 'alice', 'cherry', 'dragonfruit', 'watermelon', 'lime', 'desert']
# ['peter', 'eric', 'arnold', 'classical', 'pop', 'rock', 'sept', 'jan', 'april', 'watermelon', 'desert', 'cherry', 'swede', 'dane', 'brit', 'white', 'red', 'yellow']
# ['arnold', 'eric', 'bob', 'peter', 'carol', 'alice', 'fred', 'bella', 'timothy', 'meredith', 'samantha', 'alice', 'pizza', 'stir fry', 'grilled cheese', 'spaghetti', 'soup', 'stew', 'rabbit', 'fish', 'cat', 'dog', 'bird', 'hamster', 'may', 'sept', 'mar', 'jan', 'april', 'feb', 'water', 'milk', 'coffee', 'tea', 'boba tea', 'root beer']
# ['peter', 'alice', 'eric', 'arnold', 'bob', 'lime', 'cherry', 'desert', 'dragonfruit', 'watermelon', 'grilled cheese', 'spaghetti', 'pizza', 'stew', 'stir fry', 'gray', 'black', 'red', 'brown', 'blonde']
# ['eric', 'arnold', 'peter', 'google pixel 6', 'iphone 13', 'samsung galaxy s21', 'bird', 'horse', 'cat', 'doctor', 'engineer', 'teacher', 'jan', 'sept', 'april', 'grilled cheese', 'pizza', 'spaghetti']
# ['bob', 'alice', 'arnold', 'peter', 'eric', 'carol', 'meredith', 'fred', 'timothy', 'samantha', 'bella', 'alice']
# ['peter', 'arnold', 'alice', 'eric', 'photography', 'gardening', 'cooking', 'painting']
# ['arnold', 'eric', 'horse', 'cat', 'grilled cheese', 'pizza', 'daffodils', 'carnations']
# ['arnold', 'peter', 'eric', 'alice', 'bob', 'carol', 'biography', 'science fiction', 'fantasy', 'mystery', 'romance', 'historical fiction', 'baseball', 'basketball', 'swimming', 'volleyball', 'tennis', 'soccer', 'honda civic', 'ford f150', 'tesla model 3', 'chevrolet silverado', 'bmw 3 series', 'toyota camry']
# ['alice', 'eric', 'arnold', 'peter', 'basketball', 'soccer', 'tennis', 'swimming', 'craftsman', 'victorian', 'ranch', 'colonial', 'mystery', 'science fiction', 'romance', 'fantasy']
# ['arnold', 'eric', 'peter', 'alice', 'coffee', 'water', 'tea', 'milk', 'samantha', 'meredith', 'bella', 'fred']
# ['arnold', 'eric', 'peter', 'grilled cheese', 'spaghetti', 'pizza', 'blonde', 'black', 'brown']
# ['bob', 'peter', 'arnold', 'eric', 'alice', 'bachelor', 'high school', 'master', 'associate', 'doctorate', 'craftsman', 'victorian', 'colonial', 'modern', 'ranch']
# ['bob', 'peter', 'eric', 'arnold', 'alice', 'blue', 'red', 'green', 'yellow', 'white', 'dunhill', 'prince', 'pall mall', 'blends', 'blue master', 'blonde', 'brown', 'red', 'gray', 'black', 'tea', 'milk', 'coffee', 'water', 'root beer', 'dane', 'swede', 'german', 'brit', 'norwegian']
# ['peter', 'eric', 'bob', 'alice', 'arnold', 'mystery', 'fantasy', 'science fiction', 'romance', 'biography', 'lime', 'watermelon', 'dragonfruit', 'cherry', 'desert']
# ['arnold', 'eric', 'science fiction', 'mystery', 'mountain', 'beach', 'cat', 'horse', 'rock', 'pop']
# ['bob', 'peter', 'arnold', 'eric', 'alice', 'gardening', 'painting', 'knitting', 'cooking', 'photography']
# ['alice', 'bob', 'arnold', 'carol', 'eric', 'peter', 'xiaomi mi 11', 'google pixel 6', 'samsung galaxy s21', 'oneplus 9', 'huawei p50', 'iphone 13', 'romance', 'historical fiction', 'fantasy', 'mystery', 'science fiction', 'biography', 'tulips', 'roses', 'carnations', 'daffodils', 'iris', 'lilies', 'dog', 'cat', 'bird', 'fish', 'rabbit', 'horse', 'trade school', 'high school', 'master', 'associate', 'bachelor', 'doctorate']
# ['arnold', 'eric', 'peter', 'white', 'yellow', 'red', 'city', 'mountain', 'beach', 'sept', 'april', 'jan', 'meredith', 'fred', 'bella']
# ['arnold', 'peter', 'eric', 'water', 'tea', 'milk', 'dane', 'brit', 'swede', 'mystery', 'romance', 'science fiction']
# ['eric', 'arnold', 'associate', 'high school', 'grilled cheese', 'pizza', 'daffodils', 'carnations', 'rock', 'pop']
# ['arnold', 'eric', 'desert', 'cherry', 'aniya', 'holly', 'bella', 'fred']
# ['peter', 'arnold', 'eric', 'soccer', 'basketball', 'tennis', 'cat', 'bird', 'horse', 'water', 'tea', 'milk', 'swede', 'dane', 'brit']
# ['alice', 'eric', 'peter', 'arnold', 'samsung galaxy s21', 'iphone 13', 'oneplus 9', 'google pixel 6', 'lilies', 'roses', 'carnations', 'daffodils']
# ['peter', 'eric', 'alice', 'arnold', 'carol', 'bob', 'very tall', 'very short', 'tall', 'super tall', 'short', 'average', 'cruise', 'mountain', 'camping', 'beach', 'city', 'cultural', 'blonde', 'red', 'gray', 'brown', 'auburn', 'black', 'tea', 'boba tea', 'milk', 'water', 'coffee', 'root beer', 'lilies', 'carnations', 'iris', 'tulips', 'roses', 'daffodils']
# ['carol', 'bob', 'alice', 'eric', 'arnold', 'peter', 'hamster', 'cat', 'fish', 'rabbit', 'dog', 'bird', 'blue', 'purple', 'yellow', 'white', 'red', 'green']
# ['carol', 'bob', 'arnold', 'alice', 'peter', 'eric', 'swede', 'german', 'dane', 'brit', 'chinese', 'norwegian', 'bird', 'cat', 'dog', 'rabbit', 'fish', 'hamster', 'red', 'green', 'purple', 'yellow', 'white', 'blue']
# ['eric', 'peter', 'arnold', 'associate', 'high school', 'bachelor', 'city', 'beach', 'mountain', 'classical', 'rock', 'pop', 'engineer', 'doctor', 'teacher', 'tennis', 'basketball', 'soccer']
# ['arnold', 'eric', 'brit', 'dane', 'associate', 'high school', 'april', 'sept', 'engineer', 'doctor', 'samsung galaxy s21', 'iphone 13']
# ['eric', 'arnold', 'brown', 'black']
# ['peter', 'arnold', 'eric', 'daffodils', 'carnations', 'lilies', 'samsung galaxy s21', 'iphone 13', 'google pixel 6', 'teacher', 'doctor', 'engineer', 'pall mall', 'blue master', 'prince']
# ['arnold', 'peter', 'alice', 'eric', 'yellow', 'red', 'white', 'green', 'dunhill', 'blue master', 'pall mall', 'prince', 'high school', 'associate', 'master', 'bachelor']
# ['peter', 'eric', 'alice', 'arnold', 'soccer', 'basketball', 'tennis', 'swimming', 'mountain', 'cruise', 'beach', 'city']
# ['alice', 'eric', 'peter', 'bob', 'arnold', 'colonial', 'victorian', 'craftsman', 'ranch', 'modern']
# ['bob', 'arnold', 'alice', 'peter', 'eric', 'tesla model 3', 'toyota camry', 'ford f150', 'honda civic', 'bmw 3 series', 'brit', 'norwegian', 'german', 'swede', 'dane', 'daffodils', 'carnations', 'lilies', 'tulips', 'roses']
# ['arnold', 'eric', 'samsung galaxy s21', 'iphone 13', 'water', 'tea']
# ['eric', 'arnold', 'peter', 'iphone 13', 'samsung galaxy s21', 'google pixel 6']
# ['peter', 'arnold', 'eric', 'meredith', 'bella', 'fred', 'bird', 'cat', 'horse', 'toyota camry', 'tesla model 3', 'ford f150', 'romance', 'science fiction', 'mystery', 'desert', 'watermelon', 'cherry']
# ['carol', 'bob', 'arnold', 'peter', 'alice', 'eric', 'boba tea', 'coffee', 'root beer', 'water', 'milk', 'tea', 'ranch', 'victorian', 'craftsman', 'mediterranean', 'colonial', 'modern', 'dunhill', 'prince', 'yellow monster', 'blue master', 'blends', 'pall mall']
# ['eric', 'arnold', 'associate', 'high school', 'gardening', 'photography', 'fred', 'bella', 'rock', 'pop', 'dog', 'cat']
# ['eric', 'arnold', 'red', 'yellow', 'brown', 'black', 'associate', 'high school', 'prince', 'pall mall']
# ['peter', 'eric', 'arnold', 'alice', 'jazz', 'rock', 'classical', 'pop']
# ['bob', 'peter', 'arnold', 'eric', 'alice', 'carol', 'red', 'gray', 'auburn', 'blonde', 'brown', 'black', 'historical fiction', 'biography', 'romance', 'fantasy', 'mystery', 'science fiction', 'very short', 'very tall', 'tall', 'short', 'super tall', 'average', 'associate', 'doctorate', 'high school', 'trade school', 'bachelor', 'master', 'boba tea', 'milk', 'water', 'root beer', 'coffee', 'tea']
# ['eric', 'arnold', 'tesla model 3', 'ford f150', 'cat', 'horse', 'soccer', 'basketball', 'grilled cheese', 'pizza']
# ['eric', 'arnold', 'carol', 'bob', 'peter', 'alice', 'ranch', 'victorian', 'modern', 'colonial', 'craftsman', 'mediterranean', 'coffee', 'water', 'root beer', 'tea', 'milk', 'boba tea', 'engineer', 'nurse', 'doctor', 'artist', 'lawyer', 'teacher', 'horse', 'fish', 'dog', 'cat', 'rabbit', 'bird', 'red', 'purple', 'white', 'green', 'yellow', 'blue']
# ['arnold', 'eric', 'grilled cheese', 'pizza', 'april', 'sept']
# ['bob', 'arnold', 'peter', 'alice', 'eric', 'milk', 'root beer', 'coffee', 'water', 'tea', 'dog', 'bird', 'hamster', 'cat', 'fish', 'timothy', 'meredith', 'fred', 'bella', 'samantha', 'kailyn', 'penny', 'aniya', 'janelle', 'holly', 'tennis', 'soccer', 'swimming', 'baseball', 'basketball']
# ['arnold', 'eric', 'peter', 'pop', 'rock', 'classical', 'fred', 'meredith', 'bella', 'mystery', 'romance', 'science fiction']
# ['bob', 'carol', 'alice', 'peter', 'arnold', 'eric', 'average', 'super tall', 'very short', 'short', 'very tall', 'tall', 'coffee', 'milk', 'boba tea', 'root beer', 'tea', 'water', 'blue', 'yellow', 'red', 'green', 'purple', 'white', 'mediterranean', 'colonial', 'modern', 'ranch', 'victorian', 'craftsman', 'lilies', 'roses', 'iris', 'daffodils', 'carnations', 'tulips']
# ['eric', 'alice', 'arnold', 'peter', 'master', 'high school', 'associate', 'bachelor', 'bird', 'horse', 'cat', 'fish', 'bird', 'fish', 'dog', 'cat', 'water', 'tea', 'milk', 'coffee']
# ['eric', 'alice', 'peter', 'bob', 'arnold', 'rock', 'classical', 'hip hop', 'pop', 'jazz', 'photography', 'knitting', 'cooking', 'painting', 'gardening', 'camping', 'city', 'beach', 'mountain', 'cruise', 'timothy', 'samantha', 'fred', 'bella', 'meredith', 'lilies', 'roses', 'tulips', 'carnations', 'daffodils']
# ['arnold', 'peter', 'eric', 'classical', 'pop', 'rock']
# ['peter', 'arnold', 'bob', 'alice', 'eric', 'cherry', 'lime', 'desert', 'dragonfruit', 'watermelon']
# ['arnold', 'peter', 'alice', 'bob', 'eric', 'carol', 'ranch', 'mediterranean', 'victorian', 'craftsman', 'colonial', 'modern']
# ['peter', 'eric', 'arnold', 'alice', 'april', 'sept', 'jan', 'feb', 'dunhill', 'prince', 'pall mall', 'blue master', 'google pixel 6', 'samsung galaxy s21', 'oneplus 9', 'iphone 13', 'lilies', 'roses', 'carnations', 'daffodils', 'average', 'short', 'tall', 'very short']
# ['alice', 'peter', 'arnold', 'eric', 'short', 'very short', 'tall', 'average', 'fish', 'cat', 'dog', 'bird', 'pizza', 'spaghetti', 'stew', 'grilled cheese']
# ['carol', 'bob', 'peter', 'alice', 'eric', 'arnold', 'daffodils', 'carnations', 'roses', 'iris', 'tulips', 'lilies', 'norwegian', 'dane', 'chinese', 'brit', 'german', 'swede']
# ['peter', 'arnold', 'eric', 'alice', 'kailyn', 'holly', 'aniya', 'janelle', 'dragonfruit', 'desert', 'watermelon', 'cherry', 'fantasy', 'romance', 'mystery', 'science fiction']
# ['arnold', 'eric', 'pizza', 'grilled cheese', 'cat', 'dog', 'doctor', 'engineer']
# ['eric', 'alice', 'arnold', 'peter', 'desert', 'dragonfruit', 'watermelon', 'cherry', 'gardening', 'cooking', 'photography', 'painting']
# ['arnold', 'eric', 'associate', 'high school', 'fred', 'bella', 'science fiction', 'mystery', 'cherry', 'desert']
# ['eric', 'arnold', 'water', 'tea']
# ['eric', 'carol', 'alice', 'arnold', 'peter', 'bob', 'historical fiction', 'science fiction', 'fantasy', 'romance', 'mystery', 'biography', 'iphone 13', 'google pixel 6', 'samsung galaxy s21', 'oneplus 9', 'huawei p50', 'xiaomi mi 11', 'tea', 'water', 'boba tea', 'milk', 'root beer', 'coffee']
# ['arnold', 'eric', 'cat', 'horse', 'samsung galaxy s21', 'iphone 13', 'cat', 'dog', 'pall mall', 'prince']
# ['peter', 'eric', 'bob', 'arnold', 'alice', 'mountain', 'camping', 'cruise', 'beach', 'city']
# ['arnold', 'eric', 'prince', 'pall mall', 'daffodils', 'carnations']
# ['carol', 'bob', 'peter', 'eric', 'alice', 'arnold', 'stir fry', 'grilled cheese', 'soup', 'spaghetti', 'stew', 'pizza', 'colonial', 'victorian', 'craftsman', 'mediterranean', 'ranch', 'modern']
# ['eric', 'alice', 'peter', 'arnold', 'victorian', 'ranch', 'craftsman', 'colonial', 'pall mall', 'dunhill', 'blue master', 'prince', 'doctor', 'teacher', 'engineer', 'artist', 'lilies', 'daffodils', 'roses', 'carnations', 'horse', 'bird', 'fish', 'cat']
# ['eric', 'arnold', 'victorian', 'colonial']
# ['carol', 'peter', 'bob', 'eric', 'arnold', 'alice', 'jan', 'may', 'mar', 'feb', 'april', 'sept', 'rabbit', 'bird', 'cat', 'dog', 'fish', 'hamster', 'hip hop', 'rock', 'pop', 'country', 'classical', 'jazz', 'fantasy', 'romance', 'historical fiction', 'mystery', 'biography', 'science fiction']
# ['alice', 'bob', 'peter', 'eric', 'arnold', 'associate', 'doctorate', 'bachelor', 'master', 'high school']
# ['arnold', 'peter', 'eric', 'alice', 'pizza', 'grilled cheese', 'spaghetti', 'stew']
# ['bob', 'arnold', 'peter', 'alice', 'eric', 'milk', 'root beer', 'coffee', 'tea', 'water', 'blue', 'green', 'white', 'yellow', 'red', 'daffodils', 'roses', 'lilies', 'tulips', 'carnations', 'painting', 'cooking', 'photography', 'gardening', 'knitting']
# ['eric', 'arnold', 'yellow', 'red', 'desert', 'cherry', 'fred', 'bella', 'sept', 'april', 'ford f150', 'tesla model 3']
# ['arnold', 'eric', 'peter', 'bob', 'alice', 'watermelon', 'lime', 'cherry', 'dragonfruit', 'desert', 'fish', 'bird', 'horse', 'cat', 'dog', 'camping', 'beach', 'mountain', 'city', 'cruise', 'root beer', 'water', 'milk', 'tea', 'coffee']
# ['peter', 'bob', 'arnold', 'alice', 'eric', 'cruise', 'city', 'beach', 'mountain', 'camping']
# ['peter', 'alice', 'eric', 'arnold', 'cooking', 'painting', 'gardening', 'photography', 'horse', 'fish', 'cat', 'bird', 'fantasy', 'mystery', 'romance', 'science fiction', 'april', 'jan', 'sept', 'feb', 'pop', 'rock', 'classical', 'jazz']
# ['arnold', 'eric', 'pall mall', 'prince']
# ['arnold', 'peter', 'eric', 'alice', 'bob', 'beach', 'mountain', 'cruise', 'city', 'camping', 'ranch', 'modern', 'craftsman', 'colonial', 'victorian', 'bachelor', 'doctorate', 'master', 'associate', 'high school', 'aniya', 'kailyn', 'janelle', 'penny', 'holly']
# ['peter', 'alice', 'eric', 'arnold', 'bob', 'carol', 'dane', 'brit', 'norwegian', 'swede', 'german', 'chinese', 'historical fiction', 'mystery', 'romance', 'fantasy', 'science fiction', 'biography', 'holly', 'aniya', 'penny', 'kailyn', 'sarah', 'janelle']
# ['eric', 'arnold', 'alice', 'peter', 'lilies', 'carnations', 'roses', 'daffodils', 'teacher', 'engineer', 'artist', 'doctor', 'desert', 'dragonfruit', 'watermelon', 'cherry']
# ['alice', 'eric', 'arnold', 'peter', 'prince', 'dunhill', 'blue master', 'pall mall', 'victorian', 'colonial', 'ranch', 'craftsman', 'april', 'sept', 'feb', 'jan', 'teacher', 'artist', 'doctor', 'engineer', 'samantha', 'bella', 'meredith', 'fred']
# ['eric', 'arnold', 'mystery', 'science fiction', 'tesla model 3', 'ford f150', 'photography', 'gardening', 'water', 'tea']
# ['eric', 'arnold', 'ford f150', 'tesla model 3', 'iphone 13', 'samsung galaxy s21', 'tea', 'water', 'april', 'sept', 'brit', 'dane']
# ['arnold', 'eric', 'tesla model 3', 'ford f150']
# ['peter', 'arnold', 'eric', 'alice', 'blue master', 'pall mall', 'prince', 'dunhill', 'tall', 'very short', 'average', 'short']
# ['eric', 'arnold', 'fred', 'bella']
# ['arnold', 'peter', 'eric', 'cooking', 'photography', 'gardening']
# ['eric', 'arnold', 'water', 'tea', 'engineer', 'doctor']
# ['alice', 'arnold', 'peter', 'eric', 'desert', 'watermelon', 'dragonfruit', 'cherry']
# ['arnold', 'eric', 'peter', 'pop', 'rock', 'classical', 'cat', 'horse', 'bird', 'meredith', 'bella', 'fred']
# ['eric', 'peter', 'arnold', 'victorian', 'colonial', 'ranch', 'daffodils', 'carnations', 'lilies', 'cat', 'horse', 'bird', 'swede', 'dane', 'brit']
# ['arnold', 'eric', 'carnations', 'daffodils', 'mystery', 'science fiction', 'dane', 'brit', 'horse', 'cat', 'rock', 'pop']
# ['arnold', 'bob', 'eric', 'alice', 'peter', 'cooking', 'knitting', 'gardening', 'painting', 'photography', 'hamster', 'bird', 'dog', 'fish', 'cat']
# ['peter', 'eric', 'arnold', 'black', 'brown', 'blonde', 'cat', 'horse', 'bird']
# ['eric', 'bob', 'arnold', 'peter', 'alice', 'romance', 'science fiction', 'biography', 'fantasy', 'mystery', 'camping', 'cruise', 'beach', 'mountain', 'city']
# ['arnold', 'eric', 'peter', 'alice', 'carol', 'bob', 'jazz', 'pop', 'classical', 'rock', 'hip hop', 'country']
# ['arnold', 'peter', 'eric', 'prince', 'blue master', 'pall mall']
# ['bob', 'alice', 'eric', 'arnold', 'peter', 'samantha', 'meredith', 'timothy', 'bella', 'fred', 'red', 'blonde', 'black', 'brown', 'gray', 'gardening', 'cooking', 'painting', 'knitting', 'photography', 'hamster', 'bird', 'cat', 'fish', 'dog', 'tulips', 'roses', 'carnations', 'lilies', 'daffodils']
# ['alice', 'eric', 'peter', 'arnold', 'bob', 'janelle', 'penny', 'kailyn', 'aniya', 'holly', 'black', 'red', 'blonde', 'gray', 'brown', 'doctor', 'lawyer', 'artist', 'teacher', 'engineer']
# ['alice', 'arnold', 'carol', 'peter', 'bob', 'eric', 'huawei p50', 'iphone 13', 'xiaomi mi 11', 'oneplus 9', 'samsung galaxy s21', 'google pixel 6']
# ['peter', 'eric', 'alice', 'arnold', 'brown', 'blonde', 'red', 'black', 'short', 'average', 'tall', 'very short', 'green', 'yellow', 'white', 'red']
# ['eric', 'arnold', 'peter', 'white', 'red', 'yellow', 'google pixel 6', 'samsung galaxy s21', 'iphone 13', 'lilies', 'daffodils', 'carnations', 'water', 'tea', 'milk', 'bachelor', 'associate', 'high school']
# ['eric', 'peter', 'carol', 'alice', 'arnold', 'bob', 'samantha', 'alice', 'timothy', 'fred', 'bella', 'meredith']
# ['eric', 'arnold', 'peter', 'teacher', 'doctor', 'engineer']
# ['peter', 'alice', 'bob', 'eric', 'arnold', 'very tall', 'average', 'tall', 'very short', 'short']
# ['alice', 'peter', 'carol', 'arnold', 'bob', 'eric', 'alice', 'meredith', 'samantha', 'bella', 'fred', 'timothy', 'cruise', 'camping', 'mountain', 'cultural', 'beach', 'city', 'german', 'dane', 'chinese', 'norwegian', 'swede', 'brit', 'rabbit', 'fish', 'cat', 'bird', 'dog', 'hamster']
# ['eric', 'alice', 'arnold', 'peter', 'milk', 'water', 'coffee', 'tea', 'lilies', 'roses', 'daffodils', 'carnations', 'tennis', 'basketball', 'soccer', 'swimming', 'doctor', 'teacher', 'artist', 'engineer', 'fred', 'samantha', 'bella', 'meredith']
# ['arnold', 'peter', 'eric', 'photography', 'gardening', 'cooking', 'engineer', 'teacher', 'doctor']
# ['peter', 'eric', 'arnold', 'cooking', 'gardening', 'photography']
# ['eric', 'arnold', 'associate', 'high school']
# ['alice', 'eric', 'arnold', 'peter', 'green', 'red', 'white', 'yellow']
# ['peter', 'arnold', 'eric', 'prince', 'blue master', 'pall mall']
# ['eric', 'arnold', 'victorian', 'colonial', 'very short', 'short', 'associate', 'high school']
# ['peter', 'alice', 'eric', 'arnold', 'desert', 'watermelon', 'dragonfruit', 'cherry', 'craftsman', 'victorian', 'ranch', 'colonial', 'dane', 'brit', 'norwegian', 'swede', 'google pixel 6', 'samsung galaxy s21', 'iphone 13', 'oneplus 9']
# ['eric', 'arnold', 'high school', 'associate', 'fred', 'bella', 'mountain', 'beach', 'engineer', 'doctor', 'victorian', 'colonial']
# ['eric', 'peter', 'arnold', 'jan', 'sept', 'april', 'brit', 'swede', 'dane', 'yellow', 'white', 'red']
# ['eric', 'alice', 'arnold', 'peter', 'milk', 'tea', 'coffee', 'water', 'horse', 'bird', 'fish', 'cat', 'cruise', 'city', 'mountain', 'beach']
# ['peter', 'eric', 'arnold', 'mountain', 'beach', 'city', 'cat', 'horse', 'bird', 'average', 'short', 'very short', 'fred', 'meredith', 'bella']
# ['bob', 'alice', 'eric', 'arnold', 'peter', 'aniya', 'janelle', 'penny', 'kailyn', 'holly', 'pop', 'jazz', 'rock', 'classical', 'hip hop', 'grilled cheese', 'stir fry', 'stew', 'spaghetti', 'pizza']
# ['eric', 'arnold', 'peter', 'water', 'tea', 'milk', 'cat', 'dog', 'fish', 'photography', 'cooking', 'gardening']
# ['arnold', 'peter', 'eric', 'alice', 'painting', 'gardening', 'photography', 'cooking', 'horse', 'bird', 'fish', 'cat']
# ['arnold', 'peter', 'eric', 'spaghetti', 'grilled cheese', 'pizza', 'yellow', 'white', 'red']
# ['carol', 'eric', 'arnold', 'peter', 'alice', 'bob', 'chinese', 'german', 'dane', 'norwegian', 'swede', 'brit', 'craftsman', 'colonial', 'modern', 'victorian', 'mediterranean', 'ranch']
# ['peter', 'eric', 'arnold', 'colonial', 'victorian', 'ranch', 'carnations', 'lilies', 'daffodils']
# ['alice', 'arnold', 'eric', 'peter', 'victorian', 'colonial', 'ranch', 'craftsman', 'white', 'yellow', 'green', 'red']
# ...
# ['arnold', 'peter', 'eric', 'sept', 'jan', 'april', 'photography', 'cooking', 'gardening', 'grilled cheese', 'spaghetti', 'pizza', 'science fiction', 'romance', 'mystery', 'janelle', 'holly', 'aniya']
# ['arnold', 'eric', 'peter', 'pall mall', 'blue master', 'prince', 'horse', 'cat', 'bird', 'bella', 'fred', 'meredith', 'science fiction', 'romance', 'mystery', 'google pixel 6', 'iphone 13', 'samsung galaxy s21']
# ['arnold', 'eric', 'yellow', 'red', 'beach', 'mountain', 'ford f150', 'tesla model 3', 'fred', 'bella', 'high school', 'associate']
# ['arnold', 'eric', 'peter', 'brit', 'dane', 'swede', 'janelle', 'aniya', 'holly', 'basketball', 'tennis', 'soccer', 'engineer', 'teacher', 'doctor', 'classical', 'pop', 'rock']
# ['bob', 'carol', 'arnold', 'peter', 'eric', 'alice', 'coffee', 'boba tea', 'root beer', 'water', 'tea', 'milk', 'engineer', 'doctor', 'teacher', 'nurse', 'lawyer', 'artist']
# ['arnold', 'eric', 'peter', 'bob', 'alice', 'engineer', 'doctor', 'artist', 'lawyer', 'teacher', 'cruise', 'beach', 'city', 'camping', 'mountain']
# ['alice', 'arnold', 'peter', 'eric', 'tea', 'water', 'coffee', 'milk', 'grilled cheese', 'spaghetti', 'stew', 'pizza']
# ['peter', 'eric', 'alice', 'bob', 'arnold', 'carol', 'yellow monster', 'blends', 'prince', 'dunhill', 'pall mall', 'blue master', 'xiaomi mi 11', 'iphone 13', 'google pixel 6', 'huawei p50', 'samsung galaxy s21', 'oneplus 9', 'bmw 3 series', 'honda civic', 'tesla model 3', 'ford f150', 'chevrolet silverado', 'toyota camry', 'dane', 'brit', 'chinese', 'swede', 'norwegian', 'german']
# ['peter', 'arnold', 'carol', 'alice', 'bob', 'eric', 'bachelor', 'high school', 'doctorate', 'trade school', 'associate', 'master', 'teacher', 'artist', 'nurse', 'lawyer', 'engineer', 'doctor', 'ford f150', 'toyota camry', 'honda civic', 'chevrolet silverado', 'bmw 3 series', 'tesla model 3', 'sept', 'jan', 'mar', 'april', 'feb', 'may']
# ['eric', 'arnold', 'aniya', 'holly', 'ford f150', 'tesla model 3', 'short', 'very short']
# ['carol', 'eric', 'peter', 'alice', 'bob', 'arnold', 'doctorate', 'master', 'associate', 'high school', 'bachelor', 'trade school', 'rabbit', 'fish', 'horse', 'dog', 'bird', 'cat', 'soccer', 'baseball', 'volleyball', 'basketball', 'swimming', 'tennis']
# ['bob', 'carol', 'eric', 'alice', 'peter', 'arnold', 'camping', 'cruise', 'mountain', 'cultural', 'city', 'beach', 'fish', 'hamster', 'bird', 'rabbit', 'dog', 'cat', 'brit', 'swede', 'german', 'norwegian', 'dane', 'chinese', 'biography', 'romance', 'mystery', 'fantasy', 'science fiction', 'historical fiction', 'tesla model 3', 'bmw 3 series', 'honda civic', 'chevrolet silverado', 'toyota camry', 'ford f150']
# ['eric', 'alice', 'arnold', 'carol', 'bob', 'peter', 'master', 'bachelor', 'high school', 'doctorate', 'associate', 'trade school', 'huawei p50', 'google pixel 6', 'oneplus 9', 'xiaomi mi 11', 'iphone 13', 'samsung galaxy s21']
# ['eric', 'arnold', 'colonial', 'victorian', 'april', 'sept', 'rock', 'pop']
# ['arnold', 'eric', 'peter', 'beach', 'city', 'mountain', 'soccer', 'basketball', 'tennis', 'april', 'jan', 'sept']
# ['alice', 'eric', 'peter', 'bob', 'arnold', 'red', 'white', 'green', 'blue', 'yellow', 'watermelon', 'dragonfruit', 'cherry', 'desert', 'lime', 'feb', 'sept', 'april', 'mar', 'jan', 'romance', 'science fiction', 'mystery', 'fantasy', 'biography', 'very short', 'very tall', 'tall', 'short', 'average']
# ['eric', 'peter', 'arnold', 'tea', 'water', 'milk']
# ['bob', 'arnold', 'peter', 'alice', 'eric', 'sept', 'april', 'feb', 'jan', 'mar', 'daffodils', 'lilies', 'tulips', 'carnations', 'roses']
# ['eric', 'arnold', 'beach', 'mountain', 'colonial', 'victorian']
# ['eric', 'arnold', 'basketball', 'soccer', 'photography', 'gardening']
# ['bob', 'peter', 'alice', 'eric', 'arnold', 'hamster', 'fish', 'bird', 'cat', 'dog', 'colonial', 'ranch', 'victorian', 'modern', 'craftsman', 'mar', 'sept', 'jan', 'feb', 'april', 'dog', 'cat', 'fish', 'bird', 'horse']
# ['arnold', 'eric', 'beach', 'mountain', 'cat', 'horse', 'tea', 'water', 'samsung galaxy s21', 'iphone 13', 'carnations', 'daffodils']
# ['eric', 'alice', 'peter', 'arnold', 'lilies', 'carnations', 'roses', 'daffodils', 'white', 'green', 'yellow', 'red', 'bachelor', 'associate', 'master', 'high school', 'painting', 'photography', 'gardening', 'cooking', 'dunhill', 'blue master', 'prince', 'pall mall']
# ['peter', 'arnold', 'eric', 'colonial', 'victorian', 'ranch', 'science fiction', 'mystery', 'romance', 'fish', 'cat', 'dog', 'prince', 'blue master', 'pall mall', 'cooking', 'photography', 'gardening']
# ['carol', 'bob', 'eric', 'alice', 'peter', 'arnold', 'super tall', 'tall', 'very short', 'average', 'very tall', 'short', 'google pixel 6', 'iphone 13', 'samsung galaxy s21', 'xiaomi mi 11', 'oneplus 9', 'huawei p50', 'fred', 'timothy', 'alice', 'bella', 'meredith', 'samantha']
# ['peter', 'bob', 'carol', 'eric', 'alice', 'arnold', 'bird', 'dog', 'cat', 'rabbit', 'fish', 'hamster', 'victorian', 'ranch', 'modern', 'mediterranean', 'colonial', 'craftsman', 'mar', 'sept', 'may', 'feb', 'jan', 'april']
# ['alice', 'bob', 'peter', 'eric', 'arnold', 'pall mall', 'prince', 'blends', 'dunhill', 'blue master']
# ['alice', 'peter', 'eric', 'arnold', 'bob', 'sept', 'mar', 'april', 'feb', 'jan', 'horse', 'bird', 'dog', 'fish', 'cat']
# ['carol', 'eric', 'bob', 'alice', 'peter', 'arnold', 'dog', 'horse', 'rabbit', 'bird', 'fish', 'cat', 'brown', 'black', 'blonde', 'auburn', 'red', 'gray']
# ['arnold', 'eric', 'peter', 'prince', 'pall mall', 'blue master', 'cat', 'dog', 'fish', 'janelle', 'holly', 'aniya']
# ['alice', 'peter', 'arnold', 'eric', 'teacher', 'doctor', 'engineer', 'artist', 'swede', 'dane', 'norwegian', 'brit', 'horse', 'bird', 'cat', 'fish', 'green', 'white', 'red', 'yellow', 'tennis', 'soccer', 'swimming', 'basketball']
# ['arnold', 'eric', 'brown', 'black', 'grilled cheese', 'pizza', 'pall mall', 'prince']
# ['arnold', 'eric', 'peter', 'science fiction', 'mystery', 'romance', 'bella', 'fred', 'meredith', 'black', 'blonde', 'brown', 'high school', 'associate', 'bachelor', 'daffodils', 'lilies', 'carnations']
# ['eric', 'arnold', 'engineer', 'doctor', 'samsung galaxy s21', 'iphone 13', 'brit', 'dane', 'photography', 'gardening']
# ['alice', 'peter', 'arnold', 'eric', 'cat', 'dog', 'bird', 'fish', 'holly', 'janelle', 'aniya', 'kailyn', 'colonial', 'ranch', 'victorian', 'craftsman', 'soccer', 'basketball', 'swimming', 'tennis']
# ['arnold', 'eric', 'alice', 'peter', 'horse', 'fish', 'bird', 'cat', 'basketball', 'tennis', 'swimming', 'soccer']
# ['eric', 'peter', 'arnold', 'bob', 'alice', 'brown', 'blonde', 'black', 'gray', 'red', 'beach', 'camping', 'city', 'cruise', 'mountain', 'doctor', 'lawyer', 'engineer', 'teacher', 'artist', 'jazz', 'pop', 'hip hop', 'classical', 'rock']
# ['arnold', 'eric', 'brown', 'black', 'daffodils', 'carnations']
# ['arnold', 'eric', 'bob', 'peter', 'carol', 'alice', 'lime', 'desert', 'blueberry', 'cherry', 'watermelon', 'dragonfruit']
# ['arnold', 'peter', 'eric', 'fred', 'meredith', 'bella', 'tesla model 3', 'ford f150', 'toyota camry']
# ['eric', 'alice', 'peter', 'bob', 'arnold', 'timothy', 'meredith', 'samantha', 'fred', 'bella']
# ['arnold', 'peter', 'eric', 'prince', 'pall mall', 'blue master', 'cooking', 'gardening', 'photography', 'high school', 'bachelor', 'associate', 'samsung galaxy s21', 'iphone 13', 'google pixel 6']
# ['alice', 'arnold', 'eric', 'peter', 'bob', 'carol', 'engineer', 'artist', 'doctor', 'teacher', 'nurse', 'lawyer', 'chevrolet silverado', 'ford f150', 'honda civic', 'toyota camry', 'bmw 3 series', 'tesla model 3']
# ['peter', 'arnold', 'eric', 'holly', 'janelle', 'aniya', 'classical', 'pop', 'rock', 'carnations', 'daffodils', 'lilies', 'average', 'very short', 'short', 'prince', 'pall mall', 'blue master']
# ['arnold', 'eric', 'soccer', 'basketball', 'holly', 'aniya', 'associate', 'high school']
# ['arnold', 'peter', 'eric', 'bird', 'horse', 'cat', 'jan', 'sept', 'april', 'photography', 'cooking', 'gardening', 'milk', 'water', 'tea', 'black', 'brown', 'blonde']
# ['eric', 'arnold', 'victorian', 'colonial', 'cherry', 'desert', 'dog', 'cat']
# ['eric', 'bob', 'alice', 'arnold', 'carol', 'peter', 'swede', 'norwegian', 'german', 'chinese', 'dane', 'brit', 'daffodils', 'roses', 'carnations', 'lilies', 'tulips', 'iris', 'water', 'tea', 'root beer', 'coffee', 'boba tea', 'milk', 'green', 'blue', 'purple', 'red', 'yellow', 'white', 'high school', 'associate', 'bachelor', 'doctorate', 'trade school', 'master']
# ['arnold', 'eric', 'peter', 'bird', 'horse', 'cat', 'mountain', 'city', 'beach', 'associate', 'high school', 'bachelor', 'desert', 'watermelon', 'cherry']
# ['peter', 'alice', 'bob', 'eric', 'arnold', 'dane', 'swede', 'norwegian', 'brit', 'german', 'desert', 'cherry', 'watermelon', 'dragonfruit', 'lime', 'tulips', 'roses', 'daffodils', 'carnations', 'lilies', 'ranch', 'modern', 'victorian', 'colonial', 'craftsman', 'dog', 'horse', 'bird', 'fish', 'cat']
# ['arnold', 'eric', 'peter', 'cooking', 'gardening', 'photography']
# ['arnold', 'eric', 'tesla model 3', 'ford f150', 'pall mall', 'prince', 'brit', 'dane', 'brown', 'black']
# ['alice', 'carol', 'peter', 'bob', 'arnold', 'eric', 'carnations', 'iris', 'tulips', 'daffodils', 'lilies', 'roses', 'camping', 'mountain', 'city', 'beach', 'cultural', 'cruise', 'colonial', 'modern', 'mediterranean', 'craftsman', 'ranch', 'victorian', 'short', 'very short', 'average', 'tall', 'super tall', 'very tall', 'red', 'black', 'gray', 'brown', 'auburn', 'blonde']
# ['eric', 'peter', 'arnold', 'desert', 'cherry', 'watermelon', 'city', 'mountain', 'beach', 'dane', 'brit', 'swede', 'tennis', 'soccer', 'basketball']
# ['peter', 'eric', 'arnold', 'bob', 'alice', 'carol', 'rabbit', 'dog', 'fish', 'bird', 'cat', 'horse', 'cooking', 'knitting', 'painting', 'woodworking', 'photography', 'gardening', 'basketball', 'soccer', 'swimming', 'tennis', 'baseball', 'volleyball', 'cruise', 'cultural', 'city', 'camping', 'mountain', 'beach', 'water', 'root beer', 'boba tea', 'tea', 'milk', 'coffee']
# ['alice', 'eric', 'peter', 'bob', 'arnold', 'penny', 'holly', 'janelle', 'aniya', 'kailyn', 'samantha', 'fred', 'timothy', 'meredith', 'bella', 'mystery', 'fantasy', 'biography', 'science fiction', 'romance']
# ['eric', 'arnold', 'aniya', 'holly', 'tea', 'water', 'cat', 'dog', 'engineer', 'doctor', 'carnations', 'daffodils']
# ['peter', 'bob', 'carol', 'alice', 'arnold', 'eric', 'pizza', 'stew', 'stir fry', 'soup', 'grilled cheese', 'spaghetti']
# ['bob', 'alice', 'eric', 'peter', 'arnold', 'iphone 13', 'samsung galaxy s21', 'huawei p50', 'google pixel 6', 'oneplus 9', 'soccer', 'swimming', 'baseball', 'basketball', 'tennis', 'cherry', 'dragonfruit', 'lime', 'desert', 'watermelon', 'city', 'cruise', 'beach', 'mountain', 'camping', 'horse', 'fish', 'cat', 'dog', 'bird']
# ['eric', 'arnold', 'samsung galaxy s21', 'iphone 13']
# ['alice', 'arnold', 'carol', 'peter', 'eric', 'bob', 'cat', 'bird', 'fish', 'dog', 'hamster', 'rabbit', 'super tall', 'average', 'tall', 'very short', 'very tall', 'short', 'baseball', 'tennis', 'soccer', 'swimming', 'basketball', 'volleyball']
# ['eric', 'arnold', 'carol', 'alice', 'bob', 'peter', 'bella', 'fred', 'timothy', 'alice', 'meredith', 'samantha']
# ['eric', 'arnold', 'peter', 'beach', 'mountain', 'city', 'high school', 'bachelor', 'associate', 'cat', 'bird', 'horse']
# ['arnold', 'eric', 'bob', 'alice', 'peter', 'dunhill', 'blue master', 'prince', 'blends', 'pall mall']
# ['alice', 'peter', 'eric', 'arnold', 'high school', 'bachelor', 'associate', 'master', 'romance', 'science fiction', 'mystery', 'fantasy']
# ['eric', 'peter', 'arnold', 'fish', 'dog', 'cat']
# ['alice', 'arnold', 'eric', 'peter', 'bachelor', 'associate', 'high school', 'master']
# ['peter', 'carol', 'eric', 'alice', 'bob', 'arnold', 'huawei p50', 'google pixel 6', 'xiaomi mi 11', 'iphone 13', 'samsung galaxy s21', 'oneplus 9', 'dunhill', 'pall mall', 'blends', 'blue master', 'prince', 'yellow monster', 'daffodils', 'carnations', 'roses', 'tulips', 'lilies', 'iris', 'yellow', 'red', 'green', 'blue', 'white', 'purple', 'soccer', 'tennis', 'basketball', 'volleyball', 'swimming', 'baseball']
# ['eric', 'bob', 'alice', 'peter', 'arnold', 'carnations', 'daffodils', 'tulips', 'roses', 'lilies', 'dane', 'swede', 'brit', 'norwegian', 'german', 'artist', 'lawyer', 'engineer', 'teacher', 'doctor']
# ['arnold', 'bob', 'alice', 'eric', 'peter', 'very tall', 'average', 'tall', 'very short', 'short', 'stew', 'grilled cheese', 'spaghetti', 'pizza', 'stir fry']
# ['eric', 'peter', 'arnold', 'alice', 'bob', 'associate', 'bachelor', 'high school', 'master', 'doctorate', 'swimming', 'basketball', 'tennis', 'baseball', 'soccer', 'camping', 'cruise', 'city', 'mountain', 'beach', 'google pixel 6', 'huawei p50', 'oneplus 9', 'samsung galaxy s21', 'iphone 13']
# ['arnold', 'peter', 'eric', 'beach', 'city', 'mountain']
# ['alice', 'arnold', 'eric', 'peter', 'daffodils', 'roses', 'lilies', 'carnations', 'desert', 'watermelon', 'cherry', 'dragonfruit', 'craftsman', 'colonial', 'ranch', 'victorian', 'cooking', 'photography', 'gardening', 'painting', 'coffee', 'tea', 'milk', 'water']
# ['arnold', 'eric', 'rock', 'pop']
# ['eric', 'peter', 'arnold', 'alice', 'bob', 'engineer', 'teacher', 'doctor', 'lawyer', 'artist']
# ['arnold', 'alice', 'peter', 'eric', 'roses', 'carnations', 'daffodils', 'lilies', 'victorian', 'craftsman', 'colonial', 'ranch', 'prince', 'dunhill', 'blue master', 'pall mall']
# ['arnold', 'eric', 'peter', 'google pixel 6', 'samsung galaxy s21', 'iphone 13']
# ['arnold', 'peter', 'eric', 'soccer', 'basketball', 'tennis']
# ['arnold', 'eric', 'doctor', 'engineer', 'colonial', 'victorian', 'cat', 'horse']
# ['eric', 'arnold', 'mystery', 'science fiction']
# ['eric', 'arnold', 'science fiction', 'mystery']
# ['peter', 'arnold', 'eric', 'alice', 'bird', 'fish', 'dog', 'cat']
# ['peter', 'eric', 'arnold', 'bob', 'alice', 'german', 'swede', 'brit', 'dane', 'norwegian']
# ['eric', 'arnold', 'mystery', 'science fiction', 'sept', 'april', 'red', 'yellow']
# ['arnold', 'eric', 'peter', 'alice', 'basketball', 'soccer', 'swimming', 'tennis', 'oneplus 9', 'google pixel 6', 'samsung galaxy s21', 'iphone 13', 'toyota camry', 'ford f150', 'tesla model 3', 'honda civic', 'roses', 'daffodils', 'lilies', 'carnations']
# ['eric', 'alice', 'carol', 'arnold', 'bob', 'peter', 'average', 'super tall', 'tall', 'short', 'very short', 'very tall', 'chinese', 'brit', 'german', 'swede', 'norwegian', 'dane', 'black', 'blonde', 'brown', 'auburn', 'gray', 'red']
# ['peter', 'bob', 'eric', 'arnold', 'alice', 'brown', 'black', 'gray', 'blonde', 'red', 'pall mall', 'dunhill', 'prince', 'blue master', 'blends', 'milk', 'coffee', 'water', 'tea', 'root beer', 'rock', 'classical', 'pop', 'jazz', 'hip hop']
# ['bob', 'eric', 'peter', 'alice', 'arnold', 'pizza', 'spaghetti', 'grilled cheese', 'stew', 'stir fry', 'bird', 'horse', 'cat', 'fish', 'dog', 'master', 'doctorate', 'high school', 'associate', 'bachelor']
# ['eric', 'arnold', 'gardening', 'photography', 'rock', 'pop', 'holly', 'aniya']
# ['peter', 'eric', 'arnold', 'bob', 'alice', 'fish', 'dog', 'cat', 'bird', 'hamster', 'black', 'red', 'gray', 'blonde', 'brown', 'tall', 'very tall', 'very short', 'short', 'average', 'janelle', 'penny', 'holly', 'aniya', 'kailyn']
# ['eric', 'arnold', 'pop', 'rock', 'red', 'yellow', 'soccer', 'basketball', 'brown', 'black']
# ['arnold', 'eric', 'peter', 'brit', 'dane', 'swede']
# ['eric', 'peter', 'arnold', 'water', 'tea', 'milk', 'gardening', 'photography', 'cooking']
# ['arnold', 'peter', 'eric', 'horse', 'bird', 'cat', 'pall mall', 'blue master', 'prince', 'aniya', 'holly', 'janelle']
# ['alice', 'eric', 'bob', 'peter', 'arnold', 'mar', 'april', 'sept', 'feb', 'jan', 'holly', 'janelle', 'kailyn', 'penny', 'aniya', 'engineer', 'doctor', 'lawyer', 'artist', 'teacher', 'red', 'blonde', 'black', 'gray', 'brown']
# ['arnold', 'eric', 'beach', 'mountain']
# ['eric', 'arnold', 'samsung galaxy s21', 'iphone 13', 'engineer', 'doctor', 'red', 'yellow']
# ['eric', 'arnold', 'peter', 'bob', 'alice', 'red', 'blue', 'white', 'green', 'yellow', 'blends', 'blue master', 'pall mall', 'prince', 'dunhill']

# %% [markdown]
# # Test
#
# Testing CPS components on a puzzle

# %%
colors = [
    "gelb",
    "grün",
    "weiß",
    "rot",
    "blau"
]

nationality = [
    "Norweger",
    "Ukrainer",
    "Engländer",
    "Spanier",
    "Japaner"
]

pet = [
    "Zebra",
    "Hund",
    "Schnecke",
    "Pferd",
    "Fuchs"
]

beverage = [
    "Kaffee",
    "O-Saft",
    "Milch",
    "Tee",
    "Wasser"
]

zigarette = [
    "Kools",
    "Chesterfield",
    "Old Gold",
    "Lucky Strike",
    "Parliaments"
]

values = [1, 2, 3, 4, 5]
variables = []
variables += colors
variables += nationality
variables += pet
variables += beverage
variables += zigarette


config = CpsConfiguration[str, int](variables, values)

config.allNotEqual(colors)
config.allNotEqual(nationality)
config.allNotEqual(pet)
config.allNotEqual(beverage)
config.allNotEqual(zigarette)


def next_door(a, b):
    return a == b - 1 or a == b + 1

def right_next_to(a, b):
    return (b + 1) == a 

config.equal("Engländer", "rot")
config.equal("Spanier", "Hund")
config.equal("Kaffee", "grün")
config.equal("Ukrainer", "Tee")
config.addConstraintRev("grün", "weiß", right_next_to) # a should be to the right of b (ie. one more)
config.equal("Old Gold", "Schnecke")
config.equal("Kools", "gelb")
config.mustBe("Milch", 3)
config.mustBe("Norweger", 1)
config.addConstraintRev("Chesterfield", "Fuchs", next_door)
config.addConstraintRev("Kools", "Pferd", next_door)
config.equal("Lucky Strike", "O-Saft")
config.equal("Japaner", "Parliaments")
config.addConstraintRev("Norweger", "blau", next_door)

# %%
baseState = CpsState(config)

test_state = baseState.assign("Norweger", 1).assign("Ukrainer", 2)
 
display(test_state.will_be_consistent("Spanier", 1))
display(test_state.will_be_consistent("Spanier", 2))
display(test_state.will_be_consistent("Spanier", 3))
# Out:
# False
# False
# True

# %%
baseState = CpsState[str, int](config)

for val in variables[3:8]:
    display(val, baseState.get_available_values(val))
# Out:
# 'rot'
# [1, 2, 3, 4, 5]
# 'blau'
# [1, 2, 3, 4, 5]
# 'Norweger'
# [1]
# 'Ukrainer'
# [1, 2, 3, 4, 5]
# 'Engländer'
# [1, 2, 3, 4, 5]

# %% [markdown]
# # BT-Search

# %%
from abc import abstractmethod


class BtSearchTools(Generic[TVar, TVal]):
    
    @abstractmethod
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        raise NotImplementedError()
    
    @abstractmethod
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        raise NotImplementedError()
    
    @abstractmethod
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        """
        """
        raise NotImplementedError()

# %%
class BtSearch(Generic[TVar, TVal]):
    _tool : BtSearchTools
    
    count : int
    result : CpsState[TVar, TVal] | None
    
    def __init__(self, tool: BtSearchTools):
        self._tool = tool
        self.count = 0
        
    
    @staticmethod
    def search(tool: BtSearchTools, initialState : CpsState[TVar, TVal]) -> 'BtSearch[TVar, TVal]':
        instance = BtSearch(tool)
        instance.result = instance._search(initialState)
        return instance
        
    def _search(self, state : CpsState[TVar, TVal]) -> CpsState[TVar, TVal] | None:
        
        if state.is_complete():
            return state
        
        if not state.is_consistent():
            return None
        
        self.count = self.count + 1
        
        variable = self._tool.get_next_variable(state)
        if variable is None:
            return None
        
        for value in self._tool.get_values(state, variable):
            
            if state.will_be_consistent(variable, value):
                new_state = state.assign(variable, value)
                
                if self._tool.inference(new_state, variable, value):
                    
                    result = self._search(new_state)
                    
                    if result is not None:
                        return result
        
        return None
    

def get_bt_result(bt_search : BtSearch[TVar, TVal]) -> Dict[TVal, List[TVar]]:
    
    if bt_search.result is None:
        print("No result found")
        return {}
    
    print("Step count: ", bt_search.count)
    
    d = {}
    
    assignments = bt_search.result.get_assignments()
    
    for val in bt_search.result.get_values():
        
        d[val] = bt_search.result.get_variables_with(val)
        # l = []
        
        # for var in assignments:
        #     if assignments[var] == val:
        #         l.append(var)
                
        # d[val] = l
        
    return d

# %% [markdown]
# ## Simple BT-Search
#
# This is a simple brute force search method. No fancy optimizations yet

# %%
class SimpleBtSearch(Generic[TVar, TVal], BtSearchTools[TVar, TVal]):
    
    def __init__(self):
        pass
    
    
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        
        unassigned = state.get_unassigned()
        if len(unassigned) == 0:
            return None
        return unassigned[0]
        
    
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        return state.get_values()
        
    
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        return True

# %%
result = BtSearch.search(SimpleBtSearch(), baseState)
get_bt_result(result)
# Out:
# Step count:  451
# {1: ['gelb', 'Norweger', 'Fuchs', 'Wasser', 'Kools'],
#  2: ['blau', 'Ukrainer', 'Pferd', 'Tee', 'Chesterfield'],
#  3: ['rot', 'Engländer', 'Schnecke', 'Milch', 'Old Gold'],
#  4: ['weiß', 'Spanier', 'Hund', 'O-Saft', 'Lucky Strike'],
#  5: ['grün', 'Japaner', 'Zebra', 'Kaffee', 'Parliaments']}

# %% [markdown]
# **Expected**
#
# ```
# House: 1
#   gelb
#   Norweger
#   Fuchs
#   Wasser
#   Kools
# House: 5
#   grün
#   Japaner
#   Zebra
#   Kaffee
#   Parliaments
# -- Steps: 2277
# ```

# %% [markdown]
# # BT-Search
#
# BT-Search with MRV and "Gradheuristik"
#
#  * MRV (Minimum remaining values): choose the variable with the least number of free values next
#  * Gradheuristk: if MRV returns multipel variables, choose the one with more constraints

# %%
class MrvBtSearch(Generic[TVar, TVal], BtSearchTools[TVar, TVal]):
    
    def __init__(self):
        pass
    
    
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        
        # MRV
        open_values = 10000
        variables = []
        
        for var in state.get_unassigned():
            consistent_values = 0
            
            for val in state.get_values():
                if state.will_be_consistent(var, val):
                    consistent_values = consistent_values + 1
            
            if consistent_values == 0:
                raise Exception("No consistent value found")
            
            if consistent_values > 0 and consistent_values < open_values:
                variables = [var]
                open_values = consistent_values
            
            elif consistent_values == open_values:
                variables.append(var)
                
        if len(variables) == 0:
            # something is wrong
            raise Exception("MRV selected no value")
            # return None
        
        if len(variables) == 1:
            return variables[0]
        
        
        # Gradheuristik
        variable = None
        variable_constraints = -1
        
        
        for var in variables:
            constraints = state.get_constraints_for(var)
            
            # count the number of constraints that point to unassigned variables
            c = 0
            for to in constraints:
                if to is not None and state.get_assignment(to) is None:
                    c = c + 1
                    
            if c > variable_constraints:
                variable = var
                variable_constraints = c
        
        if variable is None:
            raise Exception("Gradheuristik selected no value")
        
        return variable
        
        
    
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        return state.get_values()
        
    
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        return True

# %%
result = BtSearch.search(MrvBtSearch(), baseState)
get_bt_result(result)
# Out:
# Step count:  52
# {1: ['Norweger', 'gelb', 'Kools', 'Wasser', 'Fuchs'],
#  2: ['blau', 'Pferd', 'Ukrainer', 'Tee', 'Chesterfield'],
#  3: ['Milch', 'rot', 'Engländer', 'Old Gold', 'Schnecke'],
#  4: ['weiß', 'Spanier', 'Hund', 'O-Saft', 'Lucky Strike'],
#  5: ['grün', 'Kaffee', 'Japaner', 'Parliaments', 'Zebra']}

# %%
names = [
    "Peter",
    "Eric",
    "Arnold"
]

colors = [
    "red",
    "white",
    "yellow"
]

child = [
    "Fred",
    "Meridith",
    "Bella"
]

variables = []
variables += names
variables += colors
variables += child

values = [1, 2, 3]

config = CpsConfiguration[str, int](variables, values)

config.allNotEqual(names)
config.allNotEqual(colors)
config.allNotEqual(child)



config.equal("Arnold", "red")
config.addConstraintRev("Fred", "Eric", lambda a, b: a < b)
config.addUnaryConstraint("red", lambda a: a == 2)
config.addUnaryConstraint("Bella", lambda a: a == 1)
config.equal("white", "Meredith")


baseState = CpsState[str, int](config)
result = BtSearch.search(MrvBtSearch(), baseState)
get_bt_result(result)
# Out:
# Step count:  9
# {1: ['Bella', 'Peter', 'white'],
#  2: ['red', 'Arnold', 'Fred'],
#  3: ['Eric', 'Meridith', 'yellow']}
