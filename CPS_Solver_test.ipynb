# %%
from typing import *

# %% [markdown]
# # CPS

# %%
TVar = TypeVar('TVar')
TVal = TypeVar('TVal')

class CpsConstraint(Generic[TVal]):
    _predicates : List[Callable[[TVal, TVal], bool]]
    
    def __init__(self, predicate: Callable[[TVal, TVal], bool] = None):
        self._predicates = []
        
        if predicate is not None:
            self._predicates.append(predicate)
    
    def append(self, predicate: Callable[[TVal, TVal], bool]) -> None:
        self._predicates.append(predicate)
        
    def is_conflicting(self, a: TVal, b: TVal) -> bool:
        """
        Check if the two values a and b would conflict with any constraint
        """
        
        for p in self._predicates:
            if not p(a, b):
                return True
        return False
    
        

class CpsConfiguration(Generic[TVar, TVal]):
    _variables : List[TVar]
    _values : List[TVal]
    _constraints: Dict[TVar, Dict[TVar, CpsConstraint[TVal]]]
    
    
    def __init__(self, variables : List[str], values : List[str]):
        self._variables = variables
        self._values = values
        self._constraints = {}

    def variables(self) -> List[TVar]:
        return self._variables.copy()
    
    def values(self) -> List[TVal]:
        return self._values.copy()
    
    def _ensure_exists(self, source : TVar, target : TVar) -> None:
        if source not in self._constraints:
            self._constraints[source] = {}
        
        s = self._constraints[source]
        
        if target not in s:
            s[target] = CpsConstraint()
            
    
    def addConstraint(self, source : TVar, target : TVar, predicate : Callable[[TVal, TVal], bool]) -> None:
        """
        Add a new, one directional constraint
        """
        
        self._ensure_exists(source, target)
        
        self._constraints[source][target].append(predicate)
    
        
    def addConstraintRev(self, source : TVar, target : TVar, predicate : Callable[[TVal, TVal], bool]) -> None:
        """
        Add a new, two directional constraint.
        For the target -> source direction the parameters for the predicate are swapped, so the predicate is still called with (source, target)
        """
        
        self._ensure_exists(source, target)
        self._constraints[source][target].append(predicate)
        
        self._ensure_exists(target, source)
        self._constraints[target][source].append(lambda a, b: predicate(b, a))
    
    
    def addUnaryConstraint(self, source : TVar, predicate : Callable[[TVal], bool]) -> None:
        """
        Add a new unary constraint. 
        This is a constraint that does not have a target (eg. var must be val)
        """
        self._ensure_exists(source, None)
        
        self._constraints[source][None].append(lambda a, b: predicate(a))    
        
        
    def allNotEqual(self, variables : List[TVar]) -> None:
        """
        Constraint all variables against each other. (ie. all must have different values)
        """        
        for source in variables:
            for target in variables:
                if source == target:
                    continue
                
                self.addConstraint(source, target, lambda a, b: a != b)

                
    def notEqual(self, source : TVar, target : TVar) -> None:
        self.addConstraintRev(source, target, lambda a, b: a != b)

        
    def equal(self, source : TVar, target : TVar) -> None:
        self.addConstraintRev(source, target, lambda a, b: a == b)


    def mustBe(self, source : TVar, value : TVal) -> None:
        self.addUnaryConstraint(source, lambda a: a == value)
        

    def get_constraints(self, variable : TVar) -> Dict[TVar, CpsConstraint[TVal] ]:
        return self._constraints[variable]

# %%
class CpsState(Generic[TVar, TVal]):
    
    _parent = None
    _variable : TVar = None
    _value : TVal = None
    _config : CpsConfiguration[TVar, TVal]    
    _assigned_cache = None
    _unassigned_cache = None
    
    
    def __init__(self, config : CpsConfiguration[TVar, TVal], parent = None, variable : TVar = None, value : TVal = None):
        self._config = config
        self._parent = parent
        self._variable = variable
        self._value = value
    
    
    def assign(self, variable, value) -> 'CpsState[TVar, TVal]':
        """
        Returns a new state with the given assignment. (A state is immutable)
        """
        if variable not in self._config.variables():
            raise Exception("Invalid variable assigned: " + str(variable), ", allowed: ", self._config.variables())
        
        if value not in self._config.values():
            raise Exception("Invalid value assigned: " + str(value), ", allowed: ", self._config.values())
        
        return CpsState(self._config, self, variable, value)
    
    
    def get_assignments(self) -> Dict[TVar, TVal]:
        """
        Get all assignments
        """
        
        if self._assigned_cache is not None:
            return self._assigned_cache.copy() # return a copy so children can add to it
        
        if self._parent is None:
            return {}
        
        if self._variable is None:
            return self._parent.get_assignments()
        
        t = self._variable, self._value
        
        t2 = self._parent.get_assignments()
        t2[self._variable] = self._value
        self._assigned_cache = t2
        return t2
    
    
    def get_assignment(self, variable: TVar):
        
        assignments = self.get_assignments()
        for var in assignments:
            val = assignments[var]
            
            if var == variable:
                return val
        return None
    
    
    def get_unassigned(self) -> List[TVar]:
        """
        Get all variables that currently have no assignment
        """
        if self._unassigned_cache is not None:
            return self._unassigned_cache.copy()
        
        vars = self._config.variables()
        for a in self.get_assignments():
            if a in vars:
                vars.remove(a)
            
        self._unassigned_cache = vars
        return vars
    
    
    def get_variables(self) -> List[TVar]:
        return self._config.variables().copy()
    
    def get_values(self) -> List[TVal]:
        return self._config.values().copy()
    
    def get_constraints_for(self, variable: TVar) -> Dict[TVar, CpsConstraint[TVal]]:
        return self._config.get_constraints(variable)
    
    def is_complete(self) -> bool:
        """
        check if the CPS has assigned a value to all variables
        """
        return len(self.get_unassigned()) == 0
    
    
    def get_variables_with(self, value : TVal) -> List[TVar]:
        """
        Get all variable the value was assigned to
        """
        return [name for name, val in self.get_assignments().items() if val == value]
    
    
    def is_consistent(self) -> bool:
        
        for var in self.get_variables():
            
            # Assumes an inconsistent value was never assigned
            if self.get_assignment(var) is not None:
                continue
            
            any_consistent = False
            for val in self.get_values():
                if self.will_be_consistent(var, val):
                    any_consistent = True
            
            if not any_consistent:
                return False
        
        return True
                
    
    def will_be_consistent(self, variable: TVar, value: TVal):
        """
        Check if a variable assignment would be consistent
        """
        
        constraints = self._config.get_constraints(variable)
        
        for var in constraints:
            constraint = constraints[var] 
            
            if var is None:
                if constraint.is_conflicting(value, None):
                    return False
            else:
                otherValue = self.get_assignment(var)
                
                if otherValue is not None and constraint.is_conflicting(value, otherValue):
                    return False
                
        return True
    
    
    def get_available_values(self, variable : TVar) -> List[TVal]:
        """
        Get all values that can be assigned to variable
        """
            
        constraints = self._config.get_constraints(variable)
                   
        values = []
        
        for value in self._config.values():
        
            conflict = False
                
            for var in constraints:
                constraint = constraints[var]
                
                # if c is None it is an unary constraint
                if var is None:
                    if constraint.is_conflicting(value, None):
                        conflict = True    
                    continue
                
                otherValue = self.get_assignment(var)
                if otherValue is None: # other is not yet assigned. No check necessary
                    continue
                
                if constraint.is_conflicting(value, otherValue):
                    conflict = True
                    break
                
            if not conflict:
                values.append(value)
                
        return values

# %%
config = CpsConfiguration(["a", "b", "c"], [1, 2])
base_state = CpsState(config)

final = base_state.assign("a", 1).assign("b", 2).assign("c", 2)

display(final.is_complete())
display(final.get_variables_with(2))
# Out:
# True
# ['b', 'c']

# %% [markdown]
# # CSP Parser
#
# * Dataset: https://huggingface.co/datasets/allenai/ZebraLogicBench
#
# ### Task:
# * Read ZebraLogicBench, extract puzzles into CSP variables, domains, and constraint lists<br>
# * Example: houses, attributes, clues like “Alice lives in the red house”<br>

# %%
import pandas as pd
import re

"""
Read dataset and parse it to a dataframe
"""
zebraLogicBench = pd.read_parquet("hf://datasets/allenai/ZebraLogicBench/grid_mode/test-00000-of-00001.parquet")

"""
The column "size" tells us the number of houses and categories
(e.g. 5*6 means that we have 5 houses and 6 categories -> 30 variables)
"""

#TODO Handling categories with same values

def extract_variables(row: pd.Series) -> list[str]:
    return [v.lower() for v in re.findall(r'`([^`]+)`', str(row["puzzle"]))]

def extract_size(row: pd.Series) -> list[int]:
    size_str = row['size'].split('*')
    size_int = [int(x) for x in size_str]
    return size_int

def extract_domains(size: list[int]) -> list[int]:
    number_of_houses = size[0]
    return list(range(1, number_of_houses + 1))

def extract_clues(puzzle_text: str) -> str:
    if "## Clues:" not in puzzle_text:
        raise ValueError("No clues section found!")
    return puzzle_text.split("## Clues:", 1)[1].strip()

def extract_clue_sentences(clues : str) -> list[list[str]]:
    prepared_clues = []
    clue_sentences = re.findall(r"\d+\.\s*(.+)", clues)
    for sentence in clue_sentences:
        s = sentence.lower()
        s = re.sub(r"[^\w\s-]", "", s)
        words_of_s = s.split()
        prepared_clues.append(words_of_s)
    return prepared_clues

# TODO Parse the clue sentences
def parse_clue_sentences(clue_sentences: list[list[str]]) -> list[list[str]]:
    # first recognize constraint
    # second recognize entities
    return clue_sentences

# TODO Define and add the constraints per instance
def define_constraints(csp : CpsConfiguration, clues : str) -> None:
    parsed_clues = parse_clue_sentences(extract_clue_sentences(clues))

def all_not_equal(csp: CpsConfiguration,size: list[int], csp_variables: list[str]):
    expected_number_of_variables = size[0] * size[1]
    if expected_number_of_variables != len(csp_variables):
        raise ValueError("Number of variables does not match!")
    for j in range(size[0], size[0] * size[1] + 1, size[0]):
        csp.allNotEqual(csp_variables[j - size[0]:j])

for i, row in zebraLogicBench.iterrows():
    csp_variables = extract_variables(row)
    size = extract_size(row)
    domains_int = extract_domains(size)
    domains_str = [str(x) for x in domains_int]
    clues = extract_clues(row['puzzle'])

    csp = CpsConfiguration(csp_variables, domains_str)
    all_not_equal(csp, size, csp_variables)

    define_constraints(csp,clues)


# Parameter are two lists
# Constraint definition per methods on the instance
# csp = CpsConstraint = Dict[TVal, Callable[[TVal, TVal], bool]]
# Out:
# id                                              lgp-test-5x6-16
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Nationality', 'B...
# created_at                           2024-07-11T01:22:10.734298
# Name: 0, dtype: object
# id                                              lgp-test-4x4-27
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Occupation', 'Bo...
# created_at                           2024-07-11T01:22:10.732670
# Name: 1, dtype: object
# id                                              lgp-test-6x4-15
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Children', 'Musi...
# created_at                           2024-07-11T01:22:10.735021
# Name: 2, dtype: object
# id                                               lgp-test-6x5-2
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Mother', 'Childr...
# created_at                           2024-07-11T01:22:10.735170
# Name: 3, dtype: object
# id                                              lgp-test-2x2-33
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Pet'], 'rows': [...
# created_at                           2024-07-11T01:22:10.730172
# Name: 4, dtype: object
# id                                               lgp-test-4x4-3
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Mother', 'Birthd...
# created_at                           2024-07-11T01:22:10.732534
# Name: 5, dtype: object
# id                                               lgp-test-2x4-5
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Color'...
# created_at                           2024-07-11T01:22:10.730414
# Name: 6, dtype: object
# id                                              lgp-test-5x5-30
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Col...
# created_at                           2024-07-11T01:22:10.734145
# Name: 7, dtype: object
# id                                              lgp-test-3x5-34
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'PhoneMo...
# created_at                           2024-07-11T01:22:10.731838
# Name: 8, dtype: object
# id                                               lgp-test-4x5-3
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Mother', 'BookGe...
# created_at                           2024-07-11T01:22:10.732767
# Name: 9, dtype: object
# id                                              lgp-test-2x6-24
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'Nationali...
# created_at                           2024-07-11T01:22:10.730921
# Name: 10, dtype: object
# id                                               lgp-test-6x2-9
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Flower'], 'rows'...
# created_at                           2024-07-11T01:22:10.734487
# Name: 11, dtype: object
# id                                              lgp-test-4x2-18
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Color'], 'rows':...
# created_at                           2024-07-11T01:22:10.732172
# Name: 12, dtype: object
# id                                              lgp-test-5x2-15
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport'],...
# created_at                           2024-07-11T01:22:10.733318
# Name: 13, dtype: object
# id                                               lgp-test-5x4-2
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'PhoneMo...
# created_at                           2024-07-11T01:22:10.733716
# Name: 14, dtype: object
# id                                              lgp-test-4x4-21
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'CarModel', 'Birt...
# created_at                           2024-07-11T01:22:10.732637
# Name: 15, dtype: object
# id                                               lgp-test-5x6-0
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.734203
# Name: 16, dtype: object
# id                                               lgp-test-2x3-9
# size                                                        2*3
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'HouseStyle', 'Ph...
# created_at                           2024-07-11T01:22:10.730243
# Name: 17, dtype: object
# id                                              lgp-test-5x5-12
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Smoothie', 'Musi...
# created_at                           2024-07-11T01:22:10.734043
# Name: 18, dtype: object
# id                                              lgp-test-3x5-16
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'Favorit...
# created_at                           2024-07-11T01:22:10.731720
# Name: 19, dtype: object
# id                                              lgp-test-4x3-10
# size                                                        4*3
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'PhoneMode...
# created_at                           2024-07-11T01:22:10.732359
# Name: 20, dtype: object
# id                                              lgp-test-5x6-30
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'Cigar', '...
# created_at                           2024-07-11T01:22:10.734381
# Name: 21, dtype: object
# id                                              lgp-test-3x5-30
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre', 'Fa...
# created_at                           2024-07-11T01:22:10.731818
# Name: 22, dtype: object
# id                                              lgp-test-4x3-27
# size                                                        4*3
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre', 'Fav...
# created_at                           2024-07-11T01:22:10.732448
# Name: 23, dtype: object
# id                                              lgp-test-5x2-22
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.733357
# Name: 24, dtype: object
# id                                              lgp-test-4x3-36
# size                                                        4*3
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'HouseStyle', 'Dr...
# created_at                           2024-07-11T01:22:10.732494
# Name: 25, dtype: object
# id                                              lgp-test-5x2-14
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Food'], 'rows': ...
# created_at                           2024-07-11T01:22:10.733313
# Name: 26, dtype: object
# id                                              lgp-test-4x5-34
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Drink'...
# created_at                           2024-07-11T01:22:10.732969
# Name: 27, dtype: object
# id                                               lgp-test-3x6-5
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Occupation', 'Co...
# created_at                           2024-07-11T01:22:10.731897
# Name: 28, dtype: object
# id                                              lgp-test-5x6-10
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Nationality', 'H...
# created_at                           2024-07-11T01:22:10.734262
# Name: 29, dtype: object
# id                                              lgp-test-5x2-30
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Animal'], 'rows'...
# created_at                           2024-07-11T01:22:10.733400
# Name: 30, dtype: object
# id                                              lgp-test-6x5-20
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'Drink', ...
# created_at                           2024-07-11T01:22:10.735275
# Name: 31, dtype: object
# id                                              lgp-test-5x6-37
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Hobby', 'Favorit...
# created_at                           2024-07-11T01:22:10.734422
# Name: 32, dtype: object
# id                                              lgp-test-4x4-16
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'Animal'...
# created_at                           2024-07-11T01:22:10.732607
# Name: 33, dtype: object
# id                                               lgp-test-6x5-4
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Col...
# created_at                           2024-07-11T01:22:10.735182
# Name: 34, dtype: object
# id                                               lgp-test-3x6-9
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'CarModel', 'Hous...
# created_at                           2024-07-11T01:22:10.731917
# Name: 35, dtype: object
# id                                              lgp-test-4x6-36
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'HouseStyle', 'Mu...
# created_at                           2024-07-11T01:22:10.733215
# Name: 36, dtype: object
# id                                               lgp-test-5x5-0
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'Smoothie...
# created_at                           2024-07-11T01:22:10.733945
# Name: 37, dtype: object
# id                                              lgp-test-2x3-13
# size                                                        2*3
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Mot...
# created_at                           2024-07-11T01:22:10.730264
# Name: 38, dtype: object
# id                                              lgp-test-4x2-26
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Occupation'], 'r...
# created_at                           2024-07-11T01:22:10.732211
# Name: 39, dtype: object
# id                                              lgp-test-2x3-16
# size                                                        2*3
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'CarModel...
# created_at                           2024-07-11T01:22:10.730276
# Name: 40, dtype: object
# id                                              lgp-test-3x3-24
# size                                                        3*3
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'Childre...
# created_at                           2024-07-11T01:22:10.731335
# Name: 41, dtype: object
# id                                              lgp-test-5x6-12
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Hobby'...
# created_at                           2024-07-11T01:22:10.734274
# Name: 42, dtype: object
# id                                              lgp-test-2x6-25
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Colo...
# created_at                           2024-07-11T01:22:10.730927
# Name: 43, dtype: object
# id                                              lgp-test-4x3-26
# size                                                        4*3
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'MusicGen...
# created_at                           2024-07-11T01:22:10.732442
# Name: 44, dtype: object
# id                                              lgp-test-5x6-29
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Vacation', 'Chil...
# created_at                           2024-07-11T01:22:10.734375
# Name: 45, dtype: object
# id                                              lgp-test-2x6-14
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Pet', ...
# created_at                           2024-07-11T01:22:10.730873
# Name: 46, dtype: object
# id                                              lgp-test-2x5-30
# size                                                        2*5
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Flower...
# created_at                           2024-07-11T01:22:10.730757
# Name: 47, dtype: object
# id                                              lgp-test-5x5-21
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'BookGenre...
# created_at                           2024-07-11T01:22:10.734094
# Name: 48, dtype: object
# id                                              lgp-test-2x4-33
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'Flower'...
# created_at                           2024-07-11T01:22:10.730582
# Name: 49, dtype: object
# id                                              lgp-test-4x2-28
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'HairColor'], 'ro...
# created_at                           2024-07-11T01:22:10.732222
# Name: 50, dtype: object
# id                                               lgp-test-6x6-5
# size                                                        6*6
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre', 'Mo...
# created_at                           2024-07-11T01:22:10.735417
# Name: 51, dtype: object
# id                                              lgp-test-2x2-18
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Height'], 'rows'...
# created_at                           2024-07-11T01:22:10.730107
# Name: 52, dtype: object
# id                                              lgp-test-2x6-29
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre', 'Pe...
# created_at                           2024-07-11T01:22:10.730945
# Name: 53, dtype: object
# id                                              lgp-test-4x2-14
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Mother'], 'rows'...
# created_at                           2024-07-11T01:22:10.732153
# Name: 54, dtype: object
# id                                              lgp-test-4x6-29
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Hair...
# created_at                           2024-07-11T01:22:10.733174
# Name: 55, dtype: object
# id                                              lgp-test-5x3-26
# size                                                        5*3
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre', 'Chi...
# created_at                           2024-07-11T01:22:10.733627
# Name: 56, dtype: object
# id                                               lgp-test-5x6-3
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'Occupat...
# created_at                           2024-07-11T01:22:10.734220
# Name: 57, dtype: object
# id                                              lgp-test-3x2-21
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Height'], 'rows'...
# created_at                           2024-07-11T01:22:10.731129
# Name: 58, dtype: object
# id                                              lgp-test-4x6-26
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Mot...
# created_at                           2024-07-11T01:22:10.733158
# Name: 59, dtype: object
# id                                              lgp-test-4x6-21
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Hobby'...
# created_at                           2024-07-11T01:22:10.733130
# Name: 60, dtype: object
# id                                              lgp-test-3x4-19
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Occupation', 'Dr...
# created_at                           2024-07-11T01:22:10.731514
# Name: 61, dtype: object
# id                                              lgp-test-5x2-38
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.733442
# Name: 62, dtype: object
# id                                              lgp-test-3x6-26
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.732007
# Name: 63, dtype: object
# id                                               lgp-test-3x6-4
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.731892
# Name: 64, dtype: object
# id                                              lgp-test-6x3-39
# size                                                        6*3
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Children', 'Smoo...
# created_at                           2024-07-11T01:22:10.734903
# Name: 65, dtype: object
# id                                              lgp-test-3x5-14
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Educat...
# created_at                           2024-07-11T01:22:10.731709
# Name: 66, dtype: object
# id                                              lgp-test-2x2-16
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport'],...
# created_at                           2024-07-11T01:22:10.730097
# Name: 67, dtype: object
# id                                               lgp-test-3x2-2
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Mother'], 'rows'...
# created_at                           2024-07-11T01:22:10.731009
# Name: 68, dtype: object
# id                                               lgp-test-2x2-1
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Occupation'], 'r...
# created_at                           2024-07-11T01:22:10.730024
# Name: 69, dtype: object
# id                                              lgp-test-2x2-38
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Mother'], 'rows'...
# created_at                           2024-07-11T01:22:10.730194
# Name: 70, dtype: object
# id                                              lgp-test-3x4-10
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre', 'Foo...
# created_at                           2024-07-11T01:22:10.731464
# Name: 71, dtype: object
# id                                              lgp-test-4x4-13
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'Favorit...
# created_at                           2024-07-11T01:22:10.732591
# Name: 72, dtype: object
# id                                               lgp-test-3x3-7
# size                                                        3*3
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'HairColor', 'Bir...
# created_at                           2024-07-11T01:22:10.731252
# Name: 73, dtype: object
# id                                              lgp-test-4x4-26
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'CarModel...
# created_at                           2024-07-11T01:22:10.732665
# Name: 74, dtype: object
# id                                              lgp-test-6x4-16
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Vacation', 'Nati...
# created_at                           2024-07-11T01:22:10.735026
# Name: 75, dtype: object
# id                                              lgp-test-5x4-33
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Favori...
# created_at                           2024-07-11T01:22:10.733902
# Name: 76, dtype: object
# id                                              lgp-test-6x4-11
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'MusicG...
# created_at                           2024-07-11T01:22:10.734969
# Name: 77, dtype: object
# id                                              lgp-test-2x3-36
# size                                                        2*3
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel', 'Pe...
# created_at                           2024-07-11T01:22:10.730372
# Name: 78, dtype: object
# id                                              lgp-test-6x4-31
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Vaca...
# created_at                           2024-07-11T01:22:10.735108
# Name: 79, dtype: object
# id                                              lgp-test-5x6-32
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'Color', ...
# created_at                           2024-07-11T01:22:10.734392
# Name: 80, dtype: object
# id                                              lgp-test-4x4-28
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'Drink', ...
# created_at                           2024-07-11T01:22:10.732676
# Name: 81, dtype: object
# id                                              lgp-test-2x6-17
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'Cigar',...
# created_at                           2024-07-11T01:22:10.730887
# Name: 82, dtype: object
# id                                               lgp-test-6x3-2
# size                                                        6*3
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'BookGen...
# created_at                           2024-07-11T01:22:10.734696
# Name: 83, dtype: object
# id                                               lgp-test-3x2-0
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Pet'], 'rows': [...
# created_at                           2024-07-11T01:22:10.730999
# Name: 84, dtype: object
# id                                               lgp-test-5x6-5
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'Color',...
# created_at                           2024-07-11T01:22:10.734233
# Name: 85, dtype: object
# id                                              lgp-test-6x4-29
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Vaca...
# created_at                           2024-07-11T01:22:10.735097
# Name: 86, dtype: object
# id                                              lgp-test-3x4-13
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'MusicGen...
# created_at                           2024-07-11T01:22:10.731483
# Name: 87, dtype: object
# id                                              lgp-test-4x5-18
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'Educati...
# created_at                           2024-07-11T01:22:10.732852
# Name: 88, dtype: object
# id                                              lgp-test-2x2-24
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Nationality'], '...
# created_at                           2024-07-11T01:22:10.730134
# Name: 89, dtype: object
# id                                              lgp-test-5x4-14
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'CarMod...
# created_at                           2024-07-11T01:22:10.733788
# Name: 90, dtype: object
# id                                              lgp-test-3x2-10
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Height'], 'rows'...
# created_at                           2024-07-11T01:22:10.731049
# Name: 91, dtype: object
# id                                              lgp-test-4x2-24
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Pet'], 'rows': [...
# created_at                           2024-07-11T01:22:10.732202
# Name: 92, dtype: object
# id                                               lgp-test-4x5-8
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Birthd...
# created_at                           2024-07-11T01:22:10.732796
# Name: 93, dtype: object
# id                                              lgp-test-2x2-34
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Animal'], 'rows'...
# created_at                           2024-07-11T01:22:10.730176
# Name: 94, dtype: object
# id                                               lgp-test-6x5-8
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'Occupa...
# created_at                           2024-07-11T01:22:10.735205
# Name: 95, dtype: object
# id                                              lgp-test-3x6-38
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Dri...
# created_at                           2024-07-11T01:22:10.732073
# Name: 96, dtype: object
# id                                               lgp-test-5x2-7
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Cigar'], 'rows':...
# created_at                           2024-07-11T01:22:10.733277
# Name: 97, dtype: object
# id                                              lgp-test-3x4-18
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Nation...
# created_at                           2024-07-11T01:22:10.731509
# Name: 98, dtype: object
# id                                               lgp-test-6x3-8
# size                                                        6*3
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'Smoothi...
# created_at                           2024-07-11T01:22:10.734731
# Name: 99, dtype: object
# id                                              lgp-test-5x3-28
# size                                                        5*3
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Bir...
# created_at                           2024-07-11T01:22:10.733638
# Name: 100, dtype: object
# id                                               lgp-test-3x4-2
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'Flower'...
# created_at                           2024-07-11T01:22:10.731425
# Name: 101, dtype: object
# id                                              lgp-test-6x5-19
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.735269
# Name: 102, dtype: object
# id                                              lgp-test-6x5-24
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre', 'Ho...
# created_at                           2024-07-11T01:22:10.735297
# Name: 103, dtype: object
# id                                               lgp-test-5x2-6
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.733272
# Name: 104, dtype: object
# id                                              lgp-test-6x5-39
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre', 'Dri...
# created_at                           2024-07-11T01:22:10.735381
# Name: 105, dtype: object
# id                                              lgp-test-6x5-14
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'HairCol...
# created_at                           2024-07-11T01:22:10.735240
# Name: 106, dtype: object
# id                                              lgp-test-5x5-11
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Cigar'...
# created_at                           2024-07-11T01:22:10.734038
# Name: 107, dtype: object
# id                                               lgp-test-3x4-7
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Children', 'Nati...
# created_at                           2024-07-11T01:22:10.731450
# Name: 108, dtype: object
# id                                               lgp-test-4x5-7
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Book...
# created_at                           2024-07-11T01:22:10.732791
# Name: 109, dtype: object
# id                                               lgp-test-6x2-7
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.734477
# Name: 110, dtype: object
# id                                              lgp-test-3x2-29
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'CarModel'], 'row...
# created_at                           2024-07-11T01:22:10.731167
# Name: 111, dtype: object
# id                                              lgp-test-4x2-36
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Nationality'], '...
# created_at                           2024-07-11T01:22:10.732261
# Name: 112, dtype: object
# id                                              lgp-test-2x2-28
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Cigar'], 'rows':...
# created_at                           2024-07-11T01:22:10.730151
# Name: 113, dtype: object
# id                                              lgp-test-3x6-14
# size                                                        3*6
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'CarModel', 'Vaca...
# created_at                           2024-07-11T01:22:10.731942
# Name: 114, dtype: object
# id                                              lgp-test-6x2-19
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Food'], 'rows': ...
# created_at                           2024-07-11T01:22:10.734574
# Name: 115, dtype: object
# id                                              lgp-test-3x4-36
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Hob...
# created_at                           2024-07-11T01:22:10.731613
# Name: 116, dtype: object
# id                                               lgp-test-4x6-0
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Fav...
# created_at                           2024-07-11T01:22:10.733005
# Name: 117, dtype: object
# id                                               lgp-test-3x3-1
# size                                                        3*3
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.731223
# Name: 118, dtype: object
# id                                              lgp-test-2x5-29
# size                                                        2*5
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Nation...
# created_at                           2024-07-11T01:22:10.730752
# Name: 119, dtype: object
# id                                              lgp-test-4x4-36
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'HairColor', 'Occ...
# created_at                           2024-07-11T01:22:10.732727
# Name: 120, dtype: object
# id                                              lgp-test-4x2-17
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Food'], 'rows': ...
# created_at                           2024-07-11T01:22:10.732167
# Name: 121, dtype: object
# id                                              lgp-test-5x3-20
# size                                                        5*3
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'HairColor', 'Flo...
# created_at                           2024-07-11T01:22:10.733593
# Name: 122, dtype: object
# id                                              lgp-test-2x6-38
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'Flower', ...
# created_at                           2024-07-11T01:22:10.730990
# Name: 123, dtype: object
# id                                              lgp-test-4x6-25
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Hobby', 'BookGen...
# created_at                           2024-07-11T01:22:10.733153
# Name: 124, dtype: object
# id                                               lgp-test-3x5-5
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'CarM...
# created_at                           2024-07-11T01:22:10.731661
# Name: 125, dtype: object
# id                                              lgp-test-6x2-23
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre'], 'r...
# created_at                           2024-07-11T01:22:10.734594
# Name: 126, dtype: object
# id                                              lgp-test-5x4-22
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'Vacati...
# created_at                           2024-07-11T01:22:10.733833
# Name: 127, dtype: object
# id                                              lgp-test-6x5-29
# size                                                        6*5
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel', 'Ha...
# created_at                           2024-07-11T01:22:10.735326
# Name: 128, dtype: object
# id                                              lgp-test-4x4-35
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'BookGen...
# created_at                           2024-07-11T01:22:10.732721
# Name: 129, dtype: object
# id                                              lgp-test-6x3-24
# size                                                        6*3
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Vacation', 'Nati...
# created_at                           2024-07-11T01:22:10.734821
# Name: 130, dtype: object
# id                                              lgp-test-6x2-36
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre'], 'ro...
# created_at                           2024-07-11T01:22:10.734665
# Name: 131, dtype: object
# id                                              lgp-test-6x3-37
# size                                                        6*3
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Hobby', 'Cigar']...
# created_at                           2024-07-11T01:22:10.734893
# Name: 132, dtype: object
# id                                              lgp-test-3x5-39
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'Color'...
# created_at                           2024-07-11T01:22:10.731864
# Name: 133, dtype: object
# id                                              lgp-test-4x6-34
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'Birthda...
# created_at                           2024-07-11T01:22:10.733204
# Name: 134, dtype: object
# id                                              lgp-test-5x6-28
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.734368
# Name: 135, dtype: object
# id                                              lgp-test-2x6-28
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'HouseStyle', 'Na...
# created_at                           2024-07-11T01:22:10.730941
# Name: 136, dtype: object
# id                                              lgp-test-2x3-26
# size                                                        2*3
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Dri...
# created_at                           2024-07-11T01:22:10.730324
# Name: 137, dtype: object
# id                                              lgp-test-3x5-35
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Cigar', 'Childre...
# created_at                           2024-07-11T01:22:10.731843
# Name: 138, dtype: object
# id                                              lgp-test-5x6-39
# size                                                        5*6
# ...
# created_at                           2024-07-11T01:22:10.730802
# Name: 953, dtype: object
# id                                               lgp-test-6x6-4
# size                                                        6*6
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Vacati...
# created_at                           2024-07-11T01:22:10.735411
# Name: 954, dtype: object
# id                                              lgp-test-3x5-28
# size                                                        3*5
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Smoothie', 'Vaca...
# created_at                           2024-07-11T01:22:10.731807
# Name: 955, dtype: object
# id                                              lgp-test-6x6-23
# size                                                        6*6
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'Hobby'...
# created_at                           2024-07-11T01:22:10.735564
# Name: 956, dtype: object
# id                                              lgp-test-5x4-34
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Mother', 'Childr...
# created_at                           2024-07-11T01:22:10.733907
# Name: 957, dtype: object
# id                                               lgp-test-2x6-3
# size                                                        2*6
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Mother', 'Drink'...
# created_at                           2024-07-11T01:22:10.730820
# Name: 958, dtype: object
# id                                              lgp-test-6x2-25
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Food'], 'rows': ...
# created_at                           2024-07-11T01:22:10.734606
# Name: 959, dtype: object
# id                                              lgp-test-5x6-17
# size                                                        5*6
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel', 'Fa...
# created_at                           2024-07-11T01:22:10.734305
# Name: 960, dtype: object
# id                                               lgp-test-2x2-6
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.730049
# Name: 961, dtype: object
# id                                              lgp-test-6x4-10
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'Height', ...
# created_at                           2024-07-11T01:22:10.734964
# Name: 962, dtype: object
# id                                              lgp-test-6x2-28
# size                                                        6*2
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Children'], 'row...
# created_at                           2024-07-11T01:22:10.734621
# Name: 963, dtype: object
# id                                               lgp-test-3x4-4
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Vacation', 'Educ...
# created_at                           2024-07-11T01:22:10.731436
# Name: 964, dtype: object
# id                                               lgp-test-5x2-3
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Cigar'], 'rows':...
# created_at                           2024-07-11T01:22:10.733254
# Name: 965, dtype: object
# id                                              lgp-test-4x3-19
# size                                                        4*3
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Boo...
# created_at                           2024-07-11T01:22:10.732406
# Name: 966, dtype: object
# id                                              lgp-test-3x2-25
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Pet'], 'rows': [...
# created_at                           2024-07-11T01:22:10.731148
# Name: 967, dtype: object
# id                                              lgp-test-4x2-29
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Education'], 'ro...
# created_at                           2024-07-11T01:22:10.732227
# Name: 968, dtype: object
# id                                              lgp-test-6x6-26
# size                                                        6*6
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel', 'Ci...
# created_at                           2024-07-11T01:22:10.735582
# Name: 969, dtype: object
# id                                              lgp-test-5x4-38
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Nation...
# created_at                           2024-07-11T01:22:10.733932
# Name: 970, dtype: object
# id                                              lgp-test-5x3-25
# size                                                        5*3
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Food']...
# created_at                           2024-07-11T01:22:10.733622
# Name: 971, dtype: object
# id                                              lgp-test-5x5-13
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Education', 'Fav...
# created_at                           2024-07-11T01:22:10.734049
# Name: 972, dtype: object
# id                                               lgp-test-3x2-3
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Vacation'], 'row...
# created_at                           2024-07-11T01:22:10.731014
# Name: 973, dtype: object
# id                                              lgp-test-4x6-14
# size                                                        4*6
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'Smooth...
# created_at                           2024-07-11T01:22:10.733088
# Name: 974, dtype: object
# id                                              lgp-test-2x2-27
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre'], 'r...
# created_at                           2024-07-11T01:22:10.730146
# Name: 975, dtype: object
# id                                              lgp-test-5x2-16
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Occupation'], 'r...
# created_at                           2024-07-11T01:22:10.733324
# Name: 976, dtype: object
# id                                              lgp-test-4x4-37
# size                                                        4*4
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Flower', 'HouseS...
# created_at                           2024-07-11T01:22:10.732732
# Name: 977, dtype: object
# id                                              lgp-test-3x2-38
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel'], 'r...
# created_at                           2024-07-11T01:22:10.731209
# Name: 978, dtype: object
# id                                              lgp-test-3x2-23
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport'],...
# created_at                           2024-07-11T01:22:10.731138
# Name: 979, dtype: object
# id                                              lgp-test-2x4-15
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Occupation', 'Ho...
# created_at                           2024-07-11T01:22:10.730496
# Name: 980, dtype: object
# id                                              lgp-test-2x2-30
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre'], 'ro...
# created_at                           2024-07-11T01:22:10.730160
# Name: 981, dtype: object
# id                                              lgp-test-2x2-32
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre'], 'ro...
# created_at                           2024-07-11T01:22:10.730168
# Name: 982, dtype: object
# id                                              lgp-test-4x2-32
# size                                                        4*2
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'Pet'], 'rows': [...
# created_at                           2024-07-11T01:22:10.732242
# Name: 983, dtype: object
# id                                               lgp-test-5x2-4
# size                                                        5*2
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Nationality'], '...
# created_at                           2024-07-11T01:22:10.733259
# Name: 984, dtype: object
# id                                               lgp-test-2x4-9
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'BookGenre', 'Bir...
# created_at                           2024-07-11T01:22:10.730466
# Name: 985, dtype: object
# id                                              lgp-test-4x5-38
# size                                                        4*5
# puzzle        There are 4 houses, numbered 1 to 4 from left ...
# solution      {'header': ['House', 'Name', 'FavoriteSport', ...
# created_at                           2024-07-11T01:22:10.732993
# Name: 986, dtype: object
# id                                              lgp-test-6x4-33
# size                                                        6*4
# puzzle        There are 6 houses, numbered 1 to 6 from left ...
# solution      {'header': ['House', 'Name', 'Height', 'Nation...
# created_at                           2024-07-11T01:22:10.735119
# Name: 987, dtype: object
# id                                              lgp-test-5x5-38
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'HairColor', 'Cig...
# created_at                           2024-07-11T01:22:10.734191
# Name: 988, dtype: object
# id                                              lgp-test-5x4-12
# size                                                        5*4
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Food', 'Animal',...
# created_at                           2024-07-11T01:22:10.733776
# Name: 989, dtype: object
# id                                              lgp-test-2x4-24
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Hobby', 'MusicGe...
# created_at                           2024-07-11T01:22:10.730540
# Name: 990, dtype: object
# id                                              lgp-test-5x5-34
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Pet', 'HairColor...
# created_at                           2024-07-11T01:22:10.734169
# Name: 991, dtype: object
# id                                              lgp-test-2x5-22
# size                                                        2*5
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'MusicGenre', 'Co...
# created_at                           2024-07-11T01:22:10.730718
# Name: 992, dtype: object
# id                                              lgp-test-3x2-28
# size                                                        3*2
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Nationality'], '...
# created_at                           2024-07-11T01:22:10.731162
# Name: 993, dtype: object
# id                                              lgp-test-3x3-10
# size                                                        3*3
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Drink', 'Hobby']...
# created_at                           2024-07-11T01:22:10.731267
# Name: 994, dtype: object
# id                                               lgp-test-3x4-1
# size                                                        3*4
# puzzle        There are 3 houses, numbered 1 to 3 from left ...
# solution      {'header': ['House', 'Name', 'Animal', 'Cigar'...
# created_at                           2024-07-11T01:22:10.731420
# Name: 995, dtype: object
# id                                              lgp-test-5x5-39
# size                                                        5*5
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Birthday', 'Moth...
# created_at                           2024-07-11T01:22:10.734197
# Name: 996, dtype: object
# id                                              lgp-test-2x2-25
# size                                                        2*2
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'Vacation'], 'row...
# created_at                           2024-07-11T01:22:10.730138
# Name: 997, dtype: object
# id                                              lgp-test-2x4-34
# size                                                        2*4
# puzzle        There are 2 houses, numbered 1 to 2 from left ...
# solution      {'header': ['House', 'Name', 'PhoneModel', 'Oc...
# created_at                           2024-07-11T01:22:10.730586
# Name: 998, dtype: object
# id                                              lgp-test-5x3-14
# size                                                        5*3
# puzzle        There are 5 houses, numbered 1 to 5 from left ...
# solution      {'header': ['House', 'Name', 'Color', 'Cigar']...
# created_at                           2024-07-11T01:22:10.733560
# Name: 999, dtype: object

# %% [markdown]
# # Test
#
# Testing CPS components on a puzzle

# %%
colors = [
    "gelb",
    "grün",
    "weiß",
    "rot",
    "blau"
]

nationality = [
    "Norweger",
    "Ukrainer",
    "Engländer",
    "Spanier",
    "Japaner"
]

pet = [
    "Zebra",
    "Hund",
    "Schnecke",
    "Pferd",
    "Fuchs"
]

beverage = [
    "Kaffee",
    "O-Saft",
    "Milch",
    "Tee",
    "Wasser"
]

zigarette = [
    "Kools",
    "Chesterfield",
    "Old Gold",
    "Lucky Strike",
    "Parliaments"
]

values = [1, 2, 3, 4, 5]
variables = []
variables += colors
variables += nationality
variables += pet
variables += beverage
variables += zigarette


config = CpsConfiguration[str, int](variables, values)

config.allNotEqual(colors)
config.allNotEqual(nationality)
config.allNotEqual(pet)
config.allNotEqual(beverage)
config.allNotEqual(zigarette)


def next_door(a, b):
    return a == b - 1 or a == b + 1

def right_next_to(a, b):
    return (b + 1) == a 

config.equal("Engländer", "rot")
config.equal("Spanier", "Hund")
config.equal("Kaffee", "grün")
config.equal("Ukrainer", "Tee")
config.addConstraintRev("grün", "weiß", right_next_to) # a should be to the right of b (ie. one more)
config.equal("Old Gold", "Schnecke")
config.equal("Kools", "gelb")
config.mustBe("Milch", 3)
config.mustBe("Norweger", 1)
config.addConstraintRev("Chesterfield", "Fuchs", next_door)
config.addConstraintRev("Kools", "Pferd", next_door)
config.equal("Lucky Strike", "O-Saft")
config.equal("Japaner", "Parliaments")
config.addConstraintRev("Norweger", "blau", next_door)

# %%
baseState = CpsState(config)

test_state = baseState.assign("Norweger", 1).assign("Ukrainer", 2)
 
display(test_state.will_be_consistent("Spanier", 1))
display(test_state.will_be_consistent("Spanier", 2))
display(test_state.will_be_consistent("Spanier", 3))
# Out:
# False
# False
# True

# %%
baseState = CpsState[str, int](config)

for val in variables[3:8]:
    display(val, baseState.get_available_values(val))
# Out:
# 'rot'
# [1, 2, 3, 4, 5]
# 'blau'
# [1, 2, 3, 4, 5]
# 'Norweger'
# [1]
# 'Ukrainer'
# [1, 2, 3, 4, 5]
# 'Engländer'
# [1, 2, 3, 4, 5]

# %% [markdown]
# # BT-Search

# %%
from abc import abstractmethod


class BtSearchTools(Generic[TVar, TVal]):
    
    @abstractmethod
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        raise NotImplementedError()
    
    @abstractmethod
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        raise NotImplementedError()
    
    @abstractmethod
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        """
        """
        raise NotImplementedError()

# %%
class BtSearch(Generic[TVar, TVal]):
    _tool : BtSearchTools
    
    count : int
    result : CpsState[TVar, TVal] | None
    
    def __init__(self, tool: BtSearchTools):
        self._tool = tool
        self.count = 0
        
    
    @staticmethod
    def search(tool: BtSearchTools, initialState : CpsState[TVar, TVal]) -> 'BtSearch[TVar, TVal]':
        instance = BtSearch(tool)
        instance.result = instance._search(initialState)
        return instance
        
    def _search(self, state : CpsState[TVar, TVal]) -> CpsState[TVar, TVal] | None:
        
        if state.is_complete():
            return state
        
        if not state.is_consistent():
            return None
        
        self.count = self.count + 1
        
        variable = self._tool.get_next_variable(state)
        if variable is None:
            return None
        
        for value in self._tool.get_values(state, variable):
            
            if state.will_be_consistent(variable, value):
                new_state = state.assign(variable, value)
                
                if self._tool.inference(new_state, variable, value):
                    
                    result = self._search(new_state)
                    
                    if result is not None:
                        return result
        
        return None
    

def get_bt_result(bt_search : BtSearch[TVar, TVal]) -> Dict[TVal, List[TVar]]:
    
    if bt_search.result is None:
        print("No result found")
        return {}
    
    print("Step count: ", bt_search.count)
    
    d = {}
    
    assignments = bt_search.result.get_assignments()
    
    for val in bt_search.result.get_values():
        
        d[val] = bt_search.result.get_variables_with(val)
        # l = []
        
        # for var in assignments:
        #     if assignments[var] == val:
        #         l.append(var)
                
        # d[val] = l
        
    return d

# %% [markdown]
# ## Simple BT-Search
#
# This is a simple brute force search method. No fancy optimizations yet

# %%
class SimpleBtSearch(Generic[TVar, TVal], BtSearchTools[TVar, TVal]):
    
    def __init__(self):
        pass
    
    
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        
        unassigned = state.get_unassigned()
        if len(unassigned) == 0:
            return None
        return unassigned[0]
        
    
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        return state.get_values()
        
    
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        return True

# %%
result = BtSearch.search(SimpleBtSearch(), baseState)
get_bt_result(result)
# Out:
# Step count:  451
# {1: ['gelb', 'Norweger', 'Fuchs', 'Wasser', 'Kools'],
#  2: ['blau', 'Ukrainer', 'Pferd', 'Tee', 'Chesterfield'],
#  3: ['rot', 'Engländer', 'Schnecke', 'Milch', 'Old Gold'],
#  4: ['weiß', 'Spanier', 'Hund', 'O-Saft', 'Lucky Strike'],
#  5: ['grün', 'Japaner', 'Zebra', 'Kaffee', 'Parliaments']}

# %% [markdown]
# **Expected**
#
# ```
# House: 1
#   gelb
#   Norweger
#   Fuchs
#   Wasser
#   Kools
# House: 5
#   grün
#   Japaner
#   Zebra
#   Kaffee
#   Parliaments
# -- Steps: 2277
# ```

# %% [markdown]
# # BT-Search
#
# BT-Search with MRV and "Gradheuristik"
#
#  * MRV (Minimum remaining values): choose the variable with the least number of free values next
#  * Gradheuristk: if MRV returns multipel variables, choose the one with more constraints

# %%
class MrvBtSearch(Generic[TVar, TVal], BtSearchTools[TVar, TVal]):
    
    def __init__(self):
        pass
    
    
    def get_next_variable(self, state : CpsState[TVar, TVal]):
        """
        Get the next variable that should be assigned
        """
        
        # MRV
        open_values = 10000
        variables = []
        
        for var in state.get_unassigned():
            consistent_values = 0
            
            for val in state.get_values():
                if state.will_be_consistent(var, val):
                    consistent_values = consistent_values + 1
            
            if consistent_values == 0:
                raise Exception("No consistent value found")
            
            if consistent_values > 0 and consistent_values < open_values:
                variables = [var]
                open_values = consistent_values
            
            elif consistent_values == open_values:
                variables.append(var)
                
        if len(variables) == 0:
            # something is wrong
            raise Exception("MRV selected no value")
            # return None
        
        if len(variables) == 1:
            return variables[0]
        
        
        # Gradheuristik
        variable = None
        variable_constraints = 0
        
        
        for var in variables:
            constraints = state.get_constraints_for(var)
            
            # count the number of constraints that point to unassigned variables
            c = 0
            for to in constraints:
                if to is not None and state.get_assignment(to) is None:
                    c = c + 1
                    
            if c > variable_constraints:
                variable = var
                variable_constraints = c
        
        if variable is None:
            raise Exception("Gradheuristik selected no value")
        
        return variable
        
        
    
    def get_values(self, state : CpsState[TVar, TVal], variable : TVar) -> List[TVal]:
        """
        """
        return state.get_values()
        
    
    def inference(self, state : CpsState[TVar, TVal], variable : TVar, value : TVal) -> bool:
        return True

# %%
result = BtSearch.search(MrvBtSearch(), baseState)
get_bt_result(result)
# Out:
# Step count:  52
# {1: ['Norweger', 'gelb', 'Kools', 'Wasser', 'Fuchs'],
#  2: ['blau', 'Pferd', 'Ukrainer', 'Tee', 'Chesterfield'],
#  3: ['Milch', 'rot', 'Engländer', 'Old Gold', 'Schnecke'],
#  4: ['weiß', 'Spanier', 'Hund', 'O-Saft', 'Lucky Strike'],
#  5: ['grün', 'Kaffee', 'Japaner', 'Parliaments', 'Zebra']}
